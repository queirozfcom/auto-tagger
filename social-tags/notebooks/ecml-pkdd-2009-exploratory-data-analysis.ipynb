# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import xml.etree.ElementTree as ET
import gc

from joblib import Parallel, delayed
from tqdm import *

# %matplotlib inline

# %%
pd.options.display.max_columns = 40

# %%
ROOT = "/media/felipe/SAMSUNG/ecml-pkdd-2009/train/2009-01-01_cleaned_post-core-2/"

# %% [markdown]
# command to clean the bibtex file to make it amenable to unix parsing:
#
#     cat bibtex | sed 's/\\n / /g' | tr -d '\r' | sed -e '1h;2,$H;$!d;g' -e 's/\\\n/ /g' | tr -s " " > bibtex-unix

# %% [markdown]
# ## bibtex

# %%
bib_path = ROOT+"bibtex-unix"
bibtex_df = pd.read_csv(bib_path,sep='\t',error_bad_lines=False,names=[
    'content_id','journal','volume','chapter','edition','month', 'day', 'booktitle', 'howPublished',
'institution', 'organization','publisher','address','school','series','bibtexKey','url','type','description','annote',
'note','pages','bKey','number','crossRef','misc','bibtexAbstract','hash0','hash1','hash2','entrytype','title','author',
'editor','year'])

# %%
bibtex_df.drop(['hash0','hash1','hash2','number','pages','volume','chapter','edition','month','day'],axis=1,inplace=True)

# %%
bibtex_df.head()
# Out:
#    content_id                             journal booktitle howPublished  \
# 0      687925                                  \N        \N           \N
# 1      687933              Matematiceskij Sbornik        \N           \N
# 2      688157                                  \N        \N           \N
# 3      688158  Computer Networks and ISDN Systems        \N           \N
# 4      688159            IEEE Intelligent Systems        \N           \N
#
#   institution organization                      publisher  \
# 0          \N           \N  American Mathematical Society
# 1          \N           \N                             \N
# 2          \N           \N                             \N
# 3          \N           \N                             \N
# 4          \N           \N                             \N
#
#                     address school  \
# 0  Providence, Rhode Island     \N
# 1                        \N     \N
# 2                        \N     \N
# 3                        \N     \N
# 4                        \N     \N
#
#                                           series           bibtexKey  \
# 0  American Mathematical Society Colloqium Publi          birkhoff40
# 1                                             \N          zaretski63
# 2                                             \N  haveliwala03second
# 3                                             \N       brin98anatomy
# 4                                             \N          HAlani2003
#
#                                             url type  \
# 0                                            \N   \N
# 1                                            \N   \N
# 2  citeseer.ist.psu.edu/haveliwala03second.html   \N
# 3                                            \N   \N
# 4                                            \N   \N
#
#                          description annote        note bKey crossRef  \
# 0  references from my diploma thesis     \N          \N   \N       \N
# 1  references from my diploma thesis     \N  (russisch)   \N       \N
# 2                                kdd     \N          \N   \N       \N
# 3                                kdd     \N          \N   \N       \N
# 4                                kdd     \N          \N   \N       \N
#
#                                                 misc bibtexAbstract entrytype  \
# 0                                                 \N             \N      book
# 1                                                 \N             \N   article
# 2  text = {T. H. Haveliwala and S. D. Kamvar. The...             \N      misc
# 3              doi = {10.1016/S0169-7552(98)00110-X}             \N   article
# 4              doi = {10.1016/S0169-7552(98)00110-X}             \N   article
#
#                                                title  \
# 0                                     Lattice Theory
# 1          Die {H}albgruppe der binären {R}elationen
# 2         The second eigenvalue of the Google matrix
# 3  {T}he {A}natomy of a {L}arge-{S}cale {H}yperte...
# 4  {I}dentifying {C}ommunities of {P}ractice thro...
#
#                                               author editor  year
# 0                                   Garrett Birkhoff     \N  1967
# 1                                      K. A. Zarecki     \N  1963
# 2                        T. Haveliwala and S. Kamvar     \N  2003
# 3                      Sergey Brin and Lawrence Page     \N  1998
# 4  Harith Alani and Srinandan Dasmahapatra and Ki...     \N  2003

# %%
bibtex_df.count()
# Out:
# content_id        22846
# journal           22788
# booktitle         22773
# howPublished      22838
# institution       22845
# organization      22845
# publisher         22765
# address           22831
# school            22814
# series            22795
# bibtexKey         22844
# url               22817
# type              22846
# description        9624
# annote            22549
# note              22811
# bKey              22845
# crossRef          22846
# misc              13878
# bibtexAbstract    22729
# entrytype         22844
# title             22844
# author            22844
# editor            22844
# year              22844
# dtype: int64

# %%
bibtex_df.dtypes
# Out:
# content_id         int64
# journal           object
# booktitle         object
# howPublished      object
# institution       object
# organization      object
# publisher         object
# address           object
# school            object
# series            object
# bibtexKey         object
# url               object
# type              object
# description       object
# annote            object
# note              object
# bKey              object
# crossRef          object
# misc              object
# bibtexAbstract    object
# entrytype         object
# title             object
# author            object
# editor            object
# year              object
# dtype: object

# %%
bibtex_df.describe(include=['object'])
# Out:
#        journal booktitle howPublished institution organization publisher  \
# count    22788     22773        22838       22845        22845     22765
# unique    1823      3347          402         277           82      1145
# top         \N        \N           \N          \N           \N        \N
# freq     14899     14255        21986       22016        22655     13810
#
#        address school series bibtexKey    url   type description annote  \
# count    22831  22814  22795     22844  22817  22846        9624  22549
# unique     861    217    193     12311   5721    237        1733    153
# top         \N     \N     \N        \N     \N     \N       idsia     \N
# freq     17312  22322  21514       370  12353  22344        2030  22256
#
#          note   bKey crossRef   misc bibtexAbstract entrytype          title  \
# count   22811  22845    22846  13878          22729     22844          22844
# unique    468    230      240   7569           3246       776          10222
# top        \N     \N       \N     \N             \N   article  inproceedings
# freq    21782  22522    22265    636          16479      8040            232
#
#        author editor   year
# count   22844  22844  22844
# unique   8957   2181    707
# top        \N     \N   2006
# freq      465  17917   2726

# %%
# everything but '\N'
bools = bibtex_df.isin(['\\N'])

# %%
notbools = bools.isin([False])

# %%
bibtex_df[notbools].describe(include=['object'])
# Out:
#                    journal                                          booktitle  \
# count                 7889                                               8518
# unique                1822                                               3346
# top     Neural Computation  WWW '06: Proceedings of the 15th international...
# freq                   164                                                 76
#
#        howPublished institution                   organization  publisher  \
# count           852         829                            190       8955
# unique          401         276                             81       1144
# top       Paperback       IDSIA  {N}ature {P}ublishing {G}roup  ACM Press
# freq             86          74                             14       1113
#
#                   address             school  \
# count                5519                492
# unique                860                216
# top     New York, NY, USA  New York, NY, USA
# freq                 1404                 31
#
#                                    series bibtexKey  \
# count                                1281     22474
# unique                                192     12310
# top     Lecture Notes in Computer Science       evr
# freq                                  397       251
#
#                                        url                            type  \
# count                                10464                             502
# unique                                5720                             236
# top     http://arxiv.org/abs/cs.DL/0508082  http://semwiki.org/semwiki2006
# freq                                    39                              53
#
#        description                                             annote  \
# count         8640                                                293
# unique        1732                                                152
# top          idsia  All references containing the term "wiki" from...
# freq          2030                                                 42
#
#                                                      note   bKey  \
# count                                                1029    323
# unique                                                467    229
# top     {\\em Togelius is working at IDSIA on SNF gran...  atick
# freq                                                   38      6
#
#                                                  crossRef               misc  \
# count                                                 581              13242
# unique                                                239               7568
# top     http://data.semanticweb.org/conference/iswc-as...  comment = {alpha}
# freq                                                   45                165
#
#                                      bibtexAbstract entrytype          title  \
# count                                          6250     22826          22837
# unique                                         3245       775          10221
# top     owner = {voelkel}, timestamp = {2006.06.14}   article  inproceedings
# freq                                             49      8040            232
#
#                 author editor   year
# count            22379   4927  22279
# unique            8956   2180    706
# top     J. Schmidhuber      \   2006
# freq               222     72   2726

# %% [markdown]
# ## bookmark

# %% [markdown]
# command to clean the bookmark file to make it amenable to unix parsing:
#
#     cat bookmark | sed 's/\\n / /g' | tr -d '\r' | sed -e '1h;2,$H;$!d;g' -e 's/\\\n/ /g' | sed 's/\xe2\x80\x9c/"/g' |  tr -s " " > bookmark-unix

# %%
bookmark_path = ROOT+"bookmark-unix"
bookmark_df = pd.read_csv(bookmark_path,sep='\t',error_bad_lines=False,names=[
    'content_id','url_hash','url','description','extended_description','date'])

# %%
bookmark_df.head()
# Out:
#    content_id                          url_hash  \
# 0           8  7edfc1f9560521e83bcf5a5768889c6c
# 1          11  e636edf2736cfc61897bf21039ffea1b
# 2          12  2f87c060c8ada01d4500e8a27749dee8
# 3          13  bfb258bc024470f88f8d38c2c4d820ab
# 4          18  0f12bf6a77453df42bd6cf8ccb9ff10a
#
#                                                  url  \
# 0             http://jo.irisson.free.fr/bstdatabase/
# 1  http://acmqueue.com/modules.php?name=Content&p...
# 2  http://www.cs.stir.ac.uk/~kjt/software/latex/s...
# 3  http://virtual.cvut.cz:8080/ksmsaWeb/browser/t...
# 4   http://www.cs.utexas.edu/users/mfkb/related.html
#
#                                     description extended_description  \
# 0  LaTeX Bibliography Styles Database :: Search                  NaN
# 1          Social Bookmarking in the Enterprise                  NaN
# 2                         BibTeX Style Examples                  NaN
# 3          The KSMSA Project - Ontology Browser                  NaN
# 4               KBS/Ontology Projects Worldwide                  NaN
#
#                   date
# 0  2005-12-13 08:42:37
# 1  2005-12-07 09:08:51
# 2  2005-12-06 13:57:37
# 3  2005-12-02 09:46:10
# 4  2005-11-24 19:09:42
