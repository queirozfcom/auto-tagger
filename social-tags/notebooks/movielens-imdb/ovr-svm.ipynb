# %% [markdown]
# ## ovr-svm

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import gc
import nltk
import os
import re
import pickle
import sklearn
import sys
import string

from sklearn.metrics import f1_score, precision_score, recall_score,average_precision_score
from sklearn.model_selection import cross_val_score, GridSearchCV,ParameterGrid, train_test_split
from sklearn.multiclass import OneVsRestClassifier
from sklearn.preprocessing import MultiLabelBinarizer, StandardScaler,MinMaxScaler
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer,TfidfVectorizer
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC

from tqdm import *

# %matplotlib inline
# %load_ext autoreload
# %autoreload 1

# %%
src_dir = os.path.join(os.getcwd(), os.pardir, '../src')
sys.path.append(src_dir)

# %%
# %aimport data.movielens_20m_imdb
# %aimport helpers.labels,helpers.neighbours, helpers.segments
# %aimport utils.dataframes, utils.clusters

# %%
from data.movielens_20m_imdb import load_or_get_from_cache
from helpers.labels import truncate_labels
from helpers.neighbours import get_predicted_labels_from_neighbours
from helpers.segments import make_distance_matrix_for_segments,vectorize_segments

from utils.dataframes import sample_rows

# %%
INTERIM_DATA_ROOT = os.path.abspath("../../data/interim/movielens-ml20m-imdb/")
ML_ROOT = "/media/felipe/SAMSUNG/movielens/ml-20m/"
IMDB_ROOT = "/media/felipe/SAMSUNG/imdb/"

PATH_TO_MOVIES = ML_ROOT + "/movies.csv"
PATH_TO_TAG_ASSIGNMENTS = ML_ROOT + "/tags.csv"
PATH_TO_MOVIE_PLOTS = IMDB_ROOT+"/plot.list"

# CONFIGS

MAX_NB_WORDS = 20000
MIN_LABEL_DF = int(20)

# for sampling
NB_DOCS = 1500

# %%
docs_df = load_or_get_from_cache(PATH_TO_MOVIES,PATH_TO_TAG_ASSIGNMENTS,PATH_TO_MOVIE_PLOTS,INTERIM_DATA_ROOT)

# %%
# remove this for production
docs_df = sample_rows(docs_df,NB_DOCS)

# %%
docs_df.head()
# Out:
#    movie_id                     title  \
# 0     73256  Heart of Midnight (1988)
# 1      6281        Phone Booth (2002)
# 2      6326     City of Ghosts (2002)
# 3     87876             Cars 2 (2011)
# 4     80947       Bran Nue Dae (2009)
#
#                                          unique_tags  num_users  \
# 0       bizarre,compelling,interesting-story,betamax        2.0
# 1  colin-farrell,interesting,kiefer-sutherland,di...       40.0
# 2      gerard-depardieu,gérard-depardieu,matt-dillon        2.0
# 3  plot,not-funny,pixar,bobola,michael-caine,owen...       11.0
# 4                  geoffrey-rush,australia,road-trip        2.0
#
#    num_unique_tags                                               plot
# 0                4  Carol inherits a night club from her weird unc...
# 1               25  Stu Shepard is a fast talking and wise crackin...
# 2                3  A con man flees to Southeast Asia when an inte...
# 3               19  The famous race car Lightning McQueen and his ...
# 4                3  In the Summer of 1969 a young man is filled wi...

# %%
docs_df.describe()
# Out:
#            movie_id    num_users  num_unique_tags
# count    1500.00000  1500.000000      1500.000000
# mean    33582.07600    14.996667        11.819333
# std     37208.50344    25.735207         8.278670
# min         1.00000     2.000000         2.000000
# 25%      3750.75000     3.000000         4.000000
# 50%      7940.00000     6.000000         9.000000
# 75%     63045.25000    15.000000        19.000000
# max    128981.00000   317.000000        25.000000

# %%
truncated_labels = truncate_labels(docs_df["unique_tags"].map(lambda tagstring: tagstring.split(",")).values,MIN_LABEL_DF)

# %%
truncated_labels
# Out:
# [['betamax'],
#  ['crime', 'new-york-city', 'serial-killer', 'bad-acting'],
#  [],
#  ['not-funny', 'bobola', 'sequel'],
#  [],
#  [],
#  [],
#  ['suspense',
#   'nudity-rear',
#   'nudity-topless',
#   'silly',
#   'thriller',
#   "can't-remember",
#   'clv'],
#  ['action'],
#  ['documentary'],
#  ['less-than-300-ratings', 'crime', 'religion'],
#  ['surreal',
#   'scifi',
#   'cinematography',
#   'romance',
#   'coming-of-age',
#   'soundtrack',
#   'nudity-topless'],
#  ['betamax', 'reviewed'],
#  [],
#  ['drama'],
#  ["can't-remember", 'clv'],
#  ['animation', 'fantasy', 'funny', 'horror'],
#  ['netflix', 'to-see'],
#  ['dark-comedy'],
#  ['nudity-topless',
#   'suspense',
#   'dvdvideo',
#   'reviewed',
#   "erlend's-dvds",
#   "tumey's-dvds"],
#  ['parody',
#   'hilarious',
#   'scifi',
#   'comedy',
#   'funny',
#   'classic',
#   'seen-at-the-cinema'],
#  ['high-school',
#   'based-on-a-book',
#   'social-commentary',
#   'seen-at-the-cinema',
#   "erlend's-dvds",
#   'bibliothek'],
#  [],
#  ['politics'],
#  ['murder', 'action', 'tense', 'military', 'campy', 'crime'],
#  ['stupid', 'netflix'],
#  ['less-than-300-ratings'],
#  ['dvdvideo'],
#  ['drugs', 'comedy', 'drama', 'slow', 'movie-to-see', 'coming-of-age'],
#  ['criterion', 'bdr', 'dvdvideo'],
#  ['bdr'],
#  ['comedy', 'romance', 'less-than-300-ratings', 'funny', 'quirky'],
#  ['criterion', 'bdr', 'vhs'],
#  [],
#  ['world-war-ii', 'based-on-a-book'],
#  ['comedy'],
#  ['romance', 'comedy', 'soundtrack'],
#  ['social-commentary',
#   'animation',
#   'scifi',
#   'romance',
#   'quirky',
#   'funny',
#   'adventure',
#   'imdb-top-250',
#   'family'],
#  ['bdr'],
#  [],
#  ['nudity-topless-brief', 'england', 'r', 'tense'],
#  ['based-on-a-book', 'remake'],
#  ['action',
#   'thriller',
#   'tense',
#   'seen-more-than-once',
#   'bechdel-testfail',
#   'romance',
#   'suspense'],
#  [],
#  ['dark', 'nudity-topless', "erlend's-dvds"],
#  ['funny'],
#  ['seen-at-the-cinema'],
#  ['quirky'],
#  ['based-on-a-book', 'england', 'world-war-ii', 'bdr', 'might-like'],
#  ['betamax'],
#  [],
#  ['clv'],
#  ['cult-film', 'fantasy', 'musical', 'betamax'],
#  ['friendship', 'bechdel-testpass'],
#  ['based-on-a-book', 'bechdel-testpass'],
#  ['serial-killer',
#   'nudity-full-frontal',
#   'netflix',
#   'movie-to-see',
#   'franchise',
#   'revenge'],
#  ['drama', 'biography', 'clv', 'to-see'],
#  ['predictable', 'bechdel-testpass'],
#  [],
#  ['thriller', 'crime'],
#  ['quirky', 'comedy', 'serial-killer'],
#  ['animation', 'romance', 'drama', "can't-remember", 'classic'],
#  ['fantasy', 'betamax'],
#  ['nudity-topless', 'coming-of-age'],
#  ['dark-comedy', 'nudity-topless', 'nudity-rear', 'directorial-debut'],
#  ['criterion', 'new-york-city', 'witty', 'bdr'],
#  ['nudity-topless', 'bdr', 'betamax', 'vhs'],
#  ['new-york-city', 'bdr'],
#  ['horror',
#   'campy',
#   'humorous',
#   'nudity-full-frontal',
#   'silly',
#   'tense',
#   'based-on-a-book',
#   'adapted-frombook'],
#  ['bdr', 'dvdr', 'dvdram'],
#  ['based-on-a-book', 'adapted-frombook', 'bdr', 'clv'],
#  ['nudity-topless'],
#  ['based-on-a-book', 'true-story'],
#  [],
#  ['clv'],
#  ['bdr'],
#  ['history'],
#  ['comedy'],
#  ['less-than-300-ratings', 'bdr', "erlend's-dvds"],
#  ['dark-comedy'],
#  ['funny', 'less-than-300-ratings'],
#  ['nudity-topless'],
#  ['70mm'],
#  [],
#  ['might-like'],
#  ['seen-more-than-once'],
#  [],
#  ['disturbing', 'tense', 'betamax', 'to-see'],
#  ['documentary', 'disturbing', 'might-like', 'to-see'],
#  [],
#  ['musical', 'classic', 'funny', 'family', '70mm', 'music', 'romance'],
#  ['funny'],
#  ['bdr'],
#  ['scifi', 'directorial-debut'],
#  ['murder', 'crime', 'clearplay', 'r'],
#  ['imdb-top-250', 'crime', 'adapted-frombook', 'thriller'],
#  [],
#  ['criterion'],
#  ['new-york-city'],
#  ['betamax', 'reviewed'],
#  ['adapted-frombook', 'based-on-a-book'],
#  ['true-story', 'friendship', 'war'],
#  ['reviewed'],
#  ['thriller',
#   'horror',
#   'based-on-a-book',
#   'tense',
#   'drama',
#   'adapted-frombook'],
#  ['nudity-topless', 'sports', 'clv'],
#  ['scifi',
#   'slow',
#   'aliens',
#   'franchise',
#   "can't-remember",
#   'seen-at-the-cinema'],
#  [],
#  [],
#  ['history', 'world-war-ii', 'war', 'less-than-300-ratings'],
#  ['mental-illness',
#   'religion',
#   'true-story',
#   'based-on-a-true-story',
#   "erlend's-dvds",
#   'friendship'],
#  ['biography', 'soundtrack', 'drugs'],
#  ['nudity-topless-brief', 'clv'],
#  ['family', 'sequel', 'fantasy', 'comedy', 'remake', 'clv'],
#  [],
#  ['less-than-300-ratings', 'might-like'],
#  ['comedy', 'silly', 'music', 'soundtrack', 'drugs', 'nudity-topless'],
#  ['dark', 'dvdvideo'],
#  ['bdr'],
#  ['satire', 'social-commentary', 'clv'],
#  ['england', "can't-remember", 'comedy'],
#  ['stupid', 'horror', 'silly', 'tense', 'thriller'],
#  ['less-than-300-ratings'],
#  [],
#  ['less-than-300-ratings', 'nudity-topless-brief', 'might-like'],
#  ['campy', 'disturbing', 'quirky', 'cult-film', 'silly'],
#  ['bdr', 'dvdr', 'dvdram'],
#  ['might-like'],
#  ['politics'],
#  ['documentary',
#   'biography',
#   'disturbing',
#   'quirky',
#   'mental-illness',
#   'criterion',
#   'bdr'],
#  ['nudity-topless'],
#  ['reviewed'],
#  ['scifi',
#   'action',
#   'adventure',
#   'visually-appealing',
#   'franchise',
#   'murder',
#   'revenge'],
#  ['romance', 'soundtrack'],
#  ['nudity-topless'],
#  ['cult-film', 'scifi', 'bad-acting', 'thriller', 'directorial-debut'],
#  ['clv'],
#  ['criterion', 'vhs'],
#  ['less-than-300-ratings'],
#  ['documentary', 'quirky', 'movie-to-see', 'funny', 'seen-more-than-once'],
#  ['quirky', 'humorous', 'tense'],
#  [],
#  ['suspense',
#   'dark',
#   'nudity-topless',
#   'serial-killer',
#   'horror',
#   'boring',
#   'dvd'],
#  ['friendship',
#   'movie-to-see',
#   'suspense',
#   'bechdel-testpass',
#   'clearplay',
#   'r'],
#  ['criterion'],
#  ['netflix', 'bdr'],
#  ['boring', 'bobola'],
#  [],
#  ['bdr'],
#  ['dark',
#   'serial-killer',
#   'atmospheric',
#   'thriller',
#   'horror',
#   'nudity-full-frontal',
#   'nudity-topless',
#   'murder',
#   'england',
#   'nudity-rear'],
#  ['surreal', 'visually-appealing', 'bibliothek'],
#  ['less-than-300-ratings', 'comedy'],
#  [],
#  ['soundtrack'],
#  ["can't-remember"],
#  [],
#  ['animation', 'scifi', 'aliens', 'fatherson-relationship', 'dvdram'],
#  ['nudity-full-frontal', 'betamax'],
#  ['remake', 'adapted-frombook', 'comedy', 'based-on-a-book'],
#  ['adventure', 'bdr'],
#  [],
#  ['classic', 'seen-more-than-once'],
#  ['boring', 'not-funny', 'less-than-300-ratings'],
#  [],
#  ['surreal', 'dark-comedy', 'family', 'murder', 'action', 'quirky'],
#  ['nudity-rear', 'based-on-a-true-story', 'r', 'true-story'],
#  ['less-than-300-ratings', 'nudity-topless'],
#  ['less-than-300-ratings', 'nudity-topless'],
#  ['hilarious', 'not-funny', 'stupid', 'religion'],
#  ['quirky', 'vhs', 'bobola'],
#  ['based-on-a-book', 'new-york-city', 'bdr'],
#  ['based-on-a-book', 'clv', "erlend's-dvds"],
#  ['adapted-frombook',
#   'fantasy',
#   'stylized',
#   'based-on-a-book',
#   'romance',
#   'visually-appealing'],
#  ["can't-remember"],
#  ['atmospheric',
#   'surreal',
#   'horror',
#   'religion',
#   'suspense',
#   'based-on-a-book',
#   'imdb-top-250'],
#  ['clv'],
#  ['murder', 'funny', 'social-commentary'],
#  ['adapted-frombook',
#   'criterion',
#   'easily-confused-with-other-movies-title',
#   'bdr',
#   'dvdvideo',
#   'vhs'],
#  ['musical',
#   'anamorphic-blowup',
#   '70mm',
#   'bdr',
#   'clv',
#   'reviewed',
#   'seen-more-than-once'],
#  ['franchise', 'murder', 'betamax', 'vhs'],
#  [],
#  ['stylized',
#   'visually-appealing',
#   'quirky',
#   'funny',
#   'surreal',
#   'fantasy',
#   'music',
#   'hilarious',
#   'comedy'],
#  ['musical', 'stylized'],
#  ['might-like'],
#  ['nudity-topless'],
#  ['based-on-a-true-story', 'based-on-a-book', 'biography', 'history'],
#  ['bdr', 'betamax', 'dvdram'],
#  ['animation', "can't-remember", 'music'],
#  ["can't-remember", 'less-than-300-ratings', 'might-like'],
#  ['boring', 'aliens', 'scifi', 'bobola'],
#  ['witty', 'quirky', 'stylized', 'surreal'],
#  ['surreal', 'dark-comedy', 'quirky', 'fantasy', 'dark', 'cult-film', 'funny'],
#  [],
#  ['nudity-topless', 'biography'],
#  [],
#  [],
#  ['bdr'],
#  ['based-on-a-book'],
#  ['easily-confused-with-other-movies-title', 'surreal'],
#  ['based-on-a-book',
#   'imdb-top-250',
#   'classic',
#   'horror',
#   'adapted-frombook',
#   'dvd'],
#  ['classic', 'bdr', 'clv', 'funny', 'bibliothek'],
#  ['family', 'movie-to-see', 'comedy', 'romance'],
#  ['betamax'],
#  ['bad-acting', 'franchise'],
#  ['dark-comedy',
#   'horror',
#   'violence',
#   'not-funny',
#   "can't-remember",
#   'stylized',
#   'funny',
#   'clv',
#   'dvdram',
#   'parody',
#   'revenge'],
#  ['comedy', 'crime'],
#  ['soundtrack', 'military'],
#  ['based-on-a-book',
#   'stylized',
#   'nudity-topless-notable',
#   'nudity-topless',
#   'netflix'],
#  ['social-commentary', 'nudity-topless', 'betamax'],
#  ['murder'],
#  ['based-on-a-book', 'might-like'],
#  ['rape',
#   'atmospheric',
#   'fatherson-relationship',
#   'violence',
#   'nudity-topless',
#   'nudity-full-frontal',
#   'tense',
#   'disturbing',
#   'nudity-topless-brief'],
#  ['remake', 'clearplay', 'r'],
#  ['musical'],
#  ['less-than-300-ratings'],
#  [],
#  ['criterion', 'might-like'],
#  ['less-than-300-ratings', 'bdr'],
#  ['adventure', 'predictable', 'boring', 'sequel'],
#  [],
#  ['dark-comedy'],
#  ['less-than-300-ratings', 'reviewed'],
#  ['nudity-topless', 'clv'],
#  ['clv', 'musical'],
#  ['humorous', 'quirky'],
#  ['comedy', 'military', 'hilarious', 'clv'],
#  ['based-on-a-true-story', 'high-school'],
#  ['dark-comedy', 'hilarious'],
#  ['mental-illness', 'atmospheric', 'stylized', 'tense'],
#  ['funny'],
#  ['violence'],
#  ['violence',
#   'revenge',
#   'stylized',
#   'action',
#   'visually-appealing',
#   'quirky',
#   'funny',
#   'imdb-top-250',
#   'rape',
#   'crime'],
#  ['boring', 'based-on-a-book', 'dvdram'],
#  ['witty', 'bdr'],
#  ['comedy', 'funny'],
#  ['adventure', 'family', 'scifi', 'based-on-a-book'],
#  ['world-war-ii'],
#  [],
#  ['dvdvideo'],
#  [],
#  ['less-than-300-ratings', 'nudity-full-frontal'],
#  ['religion'],
#  ['drugs',
#   'social-commentary',
#   'surreal',
#   'based-on-a-book',
#   'disturbing',
#   'true-story',
#   'adapted-frombook'],
#  ['bdr', 'dvdram', 'dvdvideo', "tumey's-dvds"],
#  ['nudity-topless'],
#  ['nudity-topless', 'clv'],
#  [],
#  ['bobola'],
#  ['atmospheric', 'quirky', 'criterion', 'bdr', 'murder'],
#  ['politics', 'religion', 'documentary', 'violence'],
#  ['not-funny', 'predictable', 'bibliothek'],
#  ['nudity-rear', 'nudity-topless'],
#  [],
#  ['crime', 'bdr'],
#  ['classic',
#   'suspense',
#   'tense',
#   'imdb-top-250',
#   'murder',
#   'thriller',
#   'visually-appealing'],
#  ['clearplay', 'r'],
#  ['clv', 'dvdr', 'dvdram'],
#  ['world-war-ii'],
#  ['boring', 'horror', 'bad-acting', 'franchise', 'vhs'],
#  ['70mm', 'bdr', 'clv'],
#  ['based-on-a-book'],
#  ['bdr'],
#  ['betamax'],
#  ['nudity-topless'],
#  ['parody'],
#  ['bdr', 'funny'],
#  ['comedy', 'religion'],
#  ['less-than-300-ratings', 'romance', 'coming-of-age', 'reviewed'],
#  ['predictable', 'not-funny', 'movie-to-see', 'less-than-300-ratings'],
#  ['parody', 'comedy', 'imdb-top-250', 'witty'],
#  ['nudity-topless', 'social-commentary', 'reviewed'],
#  ['nudity-topless',
#   'dark-comedy',
#   'bechdel-testpass',
#   'murder',
#   'revenge',
#   'serial-killer'],
#  ["can't-remember"],
#  [],
#  [],
#  ['comedy', 'satire', 'religion', 'cult-film', 'dvdr', 'dvdram'],
#  [],
#  ['adapted-frombook', 'romance'],
#  ['sports', 'movie-to-see', 'funny', 'bibliothek'],
#  ['biography'],
#  ['world-war-ii', 'slow', 'boring', 'history', 'to-see'],
#  ['remake', 'easily-confused-with-other-movies-title'],
#  ['romance', 'friendship', 'seen-more-than-once', 'classic', 'funny'],
#  ['funny', 'horror', 'bechdel-testpass'],
#  [],
#  ['aliens', 'animation', 'funny', 'silly', 'fatherson-relationship'],
#  ['drama', 'remake'],
#  ['dvdvideo'],
#  ['criterion',
#   'nudity-topless',
#   'police',
#   'murder',
#   'disturbing',
#   "erlend's-dvds",
#   'easily-confused-with-other-movies-title'],
#  ['scifi',
#   'aliens',
#   'action',
#   'suspense',
#   'tense',
#   'military',
#   'atmospheric',
#   'classic',
#   'horror',
#   'imdb-top-250',
#   'sequel',
#   'franchise'],
#  ['war'],
#  [],
#  ['stupid', 'funny', 'comedy', 'classic', 'silly', "can't-remember"],
#  ['atmospheric', 'stylized', 'suspense', 'based-on-a-book', 'r'],
#  ['world-war-ii', 'war', 'suspense', 'nudity-rear'],
#  ['bdr', 'betamax', 'reviewed', "tumey's-dvds"],
#  ['nudity-topless', 'england', 'based-on-a-book', 'nudity-rear'],
#  ['revenge', 'remake', '70mm', 'bdr', 'dvdram', "erlend's-dvds"],
#  ['adapted-frombook', 'based-on-a-book'],
#  ['boring', 'predictable', 'slow'],
#  ['hilarious',
#   'comedy',
#   'funny',
#   'seen-more-than-once',
#   'sports',
#   'parody',
#   'bechdel-testfail',
#   'documentary'],
#  ['remake', 'netflix', 'predictable', 'bobola'],
#  [],
#  [],
#  ['military', 'clearplay', 'r'],
#  ['dark-comedy', 'nudity-topless', 'stupid', 'funny'],
#  ['betamax'],
#  ['funny', 'bibliothek'],
#  ['bechdel-testpass'],
#  ['high-school', 'parody', 'silly'],
#  [],
#  ['bdr'],
#  ['friendship', 'clv'],
#  ['action', 'silly', 'sequel', 'franchise', 'military', 'scifi'],
#  ['coming-of-age', 'romance', 'england', 'nudity-topless', 'r'],
#  ['cult-film',
#   'aliens',
#   'nudity-topless-notable',
#   'action',
#   'funny',
#   'scifi',
#   'silly',
#   '70mm',
#   'betamax'],
#  ['bibliothek'],
#  ['new-york-city'],
#  ['bdr'],
#  ['movie-to-see', 'bdr', 'reviewed'],
#  ['true-story',
#   'easily-confused-with-other-movies-title',
#   'dark',
#   'netflix',
#   'atmospheric',
#   'criterion',
#   'to-see'],
#  ['easily-confused-with-other-movies-title',
#   'action',
#   'campy',
#   'stylized',
#   'clv'],
#  ['world-war-ii'],
#  [],
#  ['70mm', 'anamorphic-blowup', 'dvdvideo'],
#  ['fatherson-relationship', 'boring', 'bechdel-testfail'],
#  ['scifi', 'seen-more-than-once'],
#  ['adapted-frombook', 'based-on-a-book', 'bdr'],
#  ['directorial-debut'],
#  ['atmospheric', 'suspense', 'drama', 'politics', 'thriller', 'murder'],
#  ['atmospheric',
#   'nudity-full-frontal',
#   'comedy',
#   'quirky',
#   'surreal',
#   'boring'],
#  [],
#  [],
#  ['parody', 'bdr'],
#  [],
#  ['animation', 'parody', 'funny', 'sequel', 'hilarious', 'comedy', 'satire'],
#  ['bdr'],
#  ['less-than-300-ratings'],
#  ['horror'],
#  ['scifi', 'criterion', 'based-on-a-book', 'bdr', 'vhs'],
#  ['nudity-full-frontal', 'nudity-topless-notable', 'drama'],
#  ['visually-appealing', 'surreal', 'scifi', 'action', 'suspense'],
#  ['cinematography', 'slow'],
#  ['humorous', 'quirky', 'stylized'],
#  ['england', 'history', 'bobola'],
#  ['netflix', 'based-on-a-book', 'drama'],
#  ['sequel', 'bobola'],
#  ['adapted-frombook',
#   'based-on-a-book',
#   'cinematography',
#   'visually-appealing'],
#  [],
#  ['fantasy',
#   'comedy',
#   'based-on-a-book',
#   'high-school',
#   'romance',
#   'funny',
#   'franchise',
#   'adapted-frombook'],
#  ['coming-of-age'],
#  ['betamax'],
#  ['documentary', 'bobola', 'drugs', 'action'],
#  ['betamax', 'dvdvideo', "tumey's-dvds"],
#  ['mental-illness', 'serial-killer', 'nudity-topless', 'dvdr'],
#  ['silly', 'social-commentary'],
#  ['dark', 'satire', 'thriller'],
#  ['funny', 'bibliothek'],
#  ['stylized', 'bdr'],
#  [],
#  ['action', 'nudity-topless', '70mm', 'anamorphic-blowup', 'betamax', 'clv'],
#  [],
#  ['movie-to-see', 'crime', 'sports', 'clearplay', 'r'],
#  ['religion', 'classic', 'high-school', 'dvdvideo'],
#  ['based-on-a-book', 'rape', 'disturbing', 'drama', 'violence'],
#  [],
#  ['bobola', 'franchise'],
#  ['scifi',
#   'predictable',
#   'stupid',
#   'action',
#   'dark',
#   'nudity-topless-notable'],
#  ['easily-confused-with-other-movies-title', 'england'],
#  [],
#  ['nudity-topless', 'murder', 'serial-killer', 'predictable', 'remake'],
#  ['religion'],
#  [],
#  ["can't-remember"],
#  ['dark', 'violence', 'stylized', 'bdr', 'rape'],
#  ['criterion',
#   'comedy',
#   'satire',
#   'social-commentary',
#   'bdr',
#   'dvdr',
#   'dvdram',
#   "tumey's-dvds"],
#  [],
#  [],
#  ['adapted-frombook',
#   'based-on-a-book',
#   'bdr',
#   'dvdr',
#   'dvdram',
#   "erlend's-dvds"],
#  ['nudity-topless-brief', 'seen-at-the-cinema', 'romance', 'based-on-a-book'],
#  ['stylized'],
#  ['dvd'],
#  ['horror', 'stupid'],
#  ['dark-comedy',
#   'musical',
#   'music',
#   'cult-film',
#   'remake',
#   '70mm',
#   'betamax',
#   'clv'],
#  ['humorous', 'quirky', 'stylized'],
#  [],
#  ['bechdel-testfail', 'high-school', 'campy'],
#  ['remake', 'hilarious', 'bechdel-testfail'],
#  ['adapted-frombook', 'clv'],
#  ['betamax', 'dvdvideo', 'reviewed', "erlend's-dvds"],
#  [],
#  ['history', '70mm', 'anamorphic-blowup', 'clv'],
#  ['friendship', 'imdb-top-250', 'humorous', 'crime', 'witty'],
#  [],
#  ['predictable',
#   'fantasy',
#   'silly',
#   'bad-acting',
#   'action',
#   'franchise',
#   'based-on-a-book'],
#  ['boring', 'silly'],
#  ['cult-film', 'aliens', 'campy', 'clv', 'dvdram', 'horror', "tumey's-dvds"],
#  ['drama', 'romance', 'politics', 'betamax', 'reviewed', 'boring', 'slow'],
#  ['might-like'],
#  ['romance', 'high-school', 'seen-more-than-once', 'directorial-debut'],
#  ['criterion', 'bdr'],
#  ['murder'],
#  ['vhs'],
#  ['serial-killer', 'dark-comedy', 'stylized', 'satire', 'violence', 'crime'],
#  ['criterion',
#   '70mm',
#   'anamorphic-blowup',
#   'bdr',
#   'betamax',
#   'dvdram',
#   'cinematography',
#   'clearplay',
#   'r',
#   "tumey's-dvds"],
#  [],
#  ['atmospheric',
#   'criterion',
#   'bdr',
#   'dvdvideo',
#   "erlend's-dvds",
#   "tumey's-dvds"],
#  ['classic', 'bdr', 'dvdram'],
#  ['satire',
#   'social-commentary',
#   'comedy',
#   'funny',
#   'r',
#   'nudity-full-frontal',
#   'new-york-city',
#   'not-funny'],
#  [],
#  ['nudity-full-frontal',
#   'less-than-300-ratings',
#   'action',
#   'police',
#   'scifi',
#   '70mm',
#   'anamorphic-blowup'],
#  ['comedy',
#   'fatherson-relationship',
#   'funny',
#   'hilarious',
#   'seen-at-the-cinema'],
#  ['movie-to-see', 'seen-at-the-cinema', 'slow', 'fatherson-relationship'],
#  ['music', 'musical', '70mm', 'bdr', "erlend's-dvds"],
#  ['nudity-topless', 'nudity-rear', 'bobola'],
#  ['dark-comedy', 'quirky'],
#  ['based-on-a-book', 'murder', 'adapted-frombook', 'drama'],
#  [],
#  ['less-than-300-ratings'],
#  ['boring', '70mm', 'clv'],
#  ['clv', 'dvdram', 'reviewed'],
#  ['religion',
#   'drama',
#   'nudity-topless-notable',
#   'revenge',
#   'murder',
#   'nudity-topless'],
#  ['criterion', 'betamax', 'dvdvideo'],
#  ['nudity-topless', 'dvdvideo'],
#  ['directorial-debut'],
#  [],
#  ['remake', 'betamax'],
#  ['boring',
#   'slow',
#   'soundtrack',
#   'nudity-full-frontal',
#   'dvdvideo',
#   'to-see',
#   'scifi'],
#  ['biography',
#   'surreal',
#   'politics',
#   'nudity-topless',
#   'nudity-full-frontal',
#   'nudity-rear'],
#  ['satire', 'dvdr'],
#  ['high-school'],
#  ['directorial-debut', 'social-commentary', 'netflix', 'nudity-topless'],
#  ['england', 'not-funny'],
#  ['action', 'campy', 'seen-at-the-cinema', 'bdr'],
#  ['based-on-a-true-story',
#   'cinematography',
#   'based-on-a-book',
#   'history',
#   'drama',
#   'soundtrack',
#   'boring'],
#  ['bdr'],
#  ['funny', 'witty', 'bdr'],
#  ['based-on-a-book', 'bdr'],
#  [],
#  ['adapted-frombook', 'rape'],
#  ['betamax'],
#  ['documentary', 'drugs', 'vhs', 'history', 'dvdr'],
#  ['funny', 'silly', 'easily-confused-with-other-movies-title', 'comedy'],
#  ['police', 'bdr', 'betamax'],
#  [],
#  ['drugs'],
#  ['revenge', 'action'],
#  ['satire', 'coming-of-age', 'campy', 'bechdel-testpass', 'funny'],
#  ['nudity-full-frontal', 'dvdram'],
#  ['aliens', 'betamax'],
#  [],
#  ["erlend's-dvds"],
#  ['franchise', 'murder', 'betamax', 'vhs'],
#  [],
#  [],
#  ['clv'],
#  [],
#  ['scifi',
#   'sequel',
#   'funny',
#   'fantasy',
#   'seen-more-than-once',
#   'humorous',
#   'adventure',
#   'classic',
#   '70mm'],
#  ['comedy'],
#  ['family', 'comedy', 'clv'],
#  ['nudity-topless'],
#  ['bdr'],
#  ['coming-of-age',
#   'mental-illness',
#   'fatherson-relationship',
#   'social-commentary',
#   'bdr',
#   'reviewed'],
#  ['drama'],
#  ['sports'],
#  [],
#  ['musical', 'drugs'],
#  ['bdr'],
#  ['easily-confused-with-other-movies-title'],
#  ['music', 'nudity-topless'],
#  ['drugs', 'nudity-topless-brief', 'nudity-topless'],
#  ['fantasy', 'bdr'],
#  ['family', 'classic', 'bdr'],
#  ['silly'],
#  ['criterion', 'bdr'],
#  ['stupid'],
#  ['nudity-topless', 'criterion', 'coming-of-age'],
#  ['social-commentary', 'might-like'],
#  [],
#  ['bdr'],
#  ['bad-acting',
#   'boring',
#   'england',
#   'world-war-ii',
#   'nudity-topless-notable',
#   'nudity-topless',
#   'bibliothek'],
#  ['revenge',
#   'drugs',
#   'atmospheric',
#   'disturbing',
#   'soundtrack',
#   'england',
#   'mental-illness',
#   'murder',
#   'slow',
#   'nudity-rear'],
#  ['crime'],
#  ['disturbing', 'stylized', 'tense', 'less-than-300-ratings'],
#  ['70mm', 'anamorphic-blowup', 'bdr'],
#  ['drama', 'comedy'],
#  ['true-story', 'politics', 'history', 'clearplay', 'r'],
#  ['aliens', 'war', 'scifi', 'adapted-frombook', 'based-on-a-book'],
#  ['bobola'],
#  ['fantasy', 'funny'],
#  ['easily-confused-with-other-movies-title', 'politics', 'comedy'],
#  ['atmospheric',
#   'nudity-topless-notable',
#   'nudity-topless',
#   'based-on-a-book',
#   'surreal',
#   "erlend's-dvds"],
#  ['drama', 'family', 'betamax', 'dvdvideo'],
#  ['funny', 'horror', 'family'],
#  [],
#  [],
#  ['comedy', 'coming-of-age', 'soundtrack', 'high-school', 'nudity-topless'],
#  ['aliens', 'horror', 'scifi'],
#  ['netflix'],
#  ['nudity-topless', 'betamax'],
#  ['friendship', 'less-than-300-ratings', 'new-york-city', 'clv'],
#  [],
#  ['bdr'],
#  ['atmospheric', 'cult-film', 'quirky', '70mm'],
#  ['police', 'betamax'],
#  ['documentary', 'new-york-city', 'to-see'],
#  ['police', 'friendship'],
#  ['hilarious'],
#  [],
#  ['action',
#   'murder',
#   'franchise',
#   'seen-at-the-cinema',
#   '70mm',
#   'anamorphic-blowup'],
#  ['clv'],
#  ['70mm', 'classic', 'less-than-300-ratings', 'based-on-a-book', 'dvdram'],
#  ['bdr', 'clv', 'vhs'],
#  [],
#  ['comedy',
#   'satire',
#   'music',
#   'r',
#   'not-funny',
#   'funny',
#   'seen-more-than-once',
#   'to-see'],
#  [],
#  ['betamax'],
#  ['drama', 'family'],
#  ['action',
#   'remake',
#   'nudity-rear',
#   'nudity-topless-brief',
#   "can't-remember",
#   'clv'],
#  ['action', 'adventure', 'scifi', 'bdr', 'dvdram', 'vhs'],
#  ['dvdvideo'],
#  [],
#  ['music', 'soundtrack'],
#  ['nudity-topless-brief', 'nudity-topless-notable', 'seen-more-than-once'],
#  ['betamax'],
#  ['parody', 'not-funny'],
#  ['high-school', 'less-than-300-ratings', 'clv'],
#  ['drama', 'romance'],
#  ['nudity-topless'],
#  ['bdr'],
#  ['quirky'],
#  ['family', 'funny', 'clv'],
#  ['nudity-topless-brief', 'nudity-rear', 'dark', 'based-on-a-book'],
#  ['nudity-topless-notable', 'based-on-a-book', 'nudity-full-frontal'],
#  ['betamax'],
#  ['religion', 'bechdel-testpass', 'clv'],
#  ['nudity-topless', 'dvd', 'horror'],
#  ['action', 'stupid', 'murder', 'funny'],
#  ['romance', 'seen-more-than-once', 'dvdvideo', "tumey's-dvds"],
#  ['romance', 'soundtrack'],
#  ['less-than-300-ratings'],
#  ['politics'],
#  ['atmospheric',
#   'nudity-topless',
#   'based-on-a-book',
#   'dark',
#   'drama',
#   'adapted-frombook'],
#  [],
#  ['bdr'],
#  ['campy', 'musical', 'humorous', 'boring', '70mm', 'bdr', 'betamax', 'dvdr'],
#  ['based-on-a-book', 'adapted-frombook', 'remake', 'drama', 'romance'],
#  ['bdr'],
#  [],
#  ['comedy', 'drama', 'not-funny', 'suspense'],
#  [],
#  ['bad-acting'],
#  ['musical'],
#  ['scifi',
#   'based-on-a-book',
#   'fantasy',
#   'aliens',
#   'action',
#   'adapted-frombook',
#   'classic'],
#  ['suspense', "can't-remember", 'bad-acting', 'clv'],
#  [],
#  ['romance', 'friendship', 'comedy', 'based-on-a-book'],
#  ['comedy',
#   'music',
#   'bechdel-testfail',
#   'seen-more-than-once',
#   'seen-at-the-cinema'],
#  ['franchise'],
#  ['clv'],
#  [],
#  ['history', 'politics', 'bdr'],
#  ['directorial-debut', 'dvdr'],
#  ['dark-comedy', 'serial-killer', 'witty', 'quirky'],
#  ['biography',
#   'based-on-a-true-story',
#   'religion',
#   'imdb-top-250',
#   'true-story',
#   'politics',
#   '70mm'],
#  [],
#  ['boring', 'vhs'],
#  ['clv'],
#  ['bdr'],
#  ['dark-comedy', 'comedy', 'not-funny', 'witty'],
#  ['comedy', 'satire'],
#  ['humorous', 'betamax'],
#  ['new-york-city', 'revenge', 'stylized'],
#  ['based-on-a-true-story', 'cinematography', 'suspense', 'true-story'],
#  ['based-on-a-true-story', 'bechdel-testpass', 'england', 'true-story'],
#  ['aliens'],
#  ['murder', 'sequel', 'scifi'],
#  ['classic', 'family', 'fatherson-relationship', 'bdr', 'bibliothek'],
#  ["can't-remember"],
#  ['bdr'],
#  ['comedy', 'bdr', 'clv', "tumey's-dvds"],
#  ['atmospheric', 'horror', 'campy', 'action', 'cult-film', 'dvdvideo'],
#  ['bdr'],
#  ['social-commentary', 'action', 'cult-film', 'dvdram'],
#  ['easily-confused-with-other-movies-title'],
#  ['history'],
#  ['murder', 'dvd'],
#  ['new-york-city', 'sports'],
#  [],
#  ['fantasy', 'visually-appealing', 'campy', 'romance', 'revenge'],
#  ['comedy',
#   'nudity-topless',
#   'action',
#   'crime',
#   "can't-remember",
#   'police',
#   'betamax',
#   'clv',
#   'reviewed'],
#  ['atmospheric',
#   'boring',
#   'funny',
#   'new-york-city',
#   'cinematography',
#   'reviewed',
#   'surreal'],
#  ['animation',
#   'funny',
#   'witty',
#   'comedy',
#   'family',
#   'humorous',
#   'adventure',
#   'fantasy',
#   'classic',
#   'imdb-top-250'],
#  [],
#  ['franchise', 'comedy', 'crime', 'police', 'seen-more-than-once', 'betamax'],
#  ['less-than-300-ratings', 'clv'],
#  ['less-than-300-ratings'],
#  ['aliens', 'music'],
#  ['boring', 'tense'],
#  ['new-york-city', 'dvd', 'movie-to-see'],
#  ['less-than-300-ratings', 'might-like'],
#  ['atmospheric',
#   'cinematography',
#   'disturbing',
#   'mental-illness',
#   'religion',
#   'violence',
#   'based-on-a-book',
#   'nudity-full-frontal',
#   'stupid',
#   'surreal'],
#  ['easily-confused-with-other-movies-title'],
#  ['animation', 'clv', 'vhs'],
#  ['world-war-ii',
#   'less-than-300-ratings',
#   'history',
#   '70mm',
#   'bdr',
#   "erlend's-dvds"],
#  ['nudity-topless-brief', 'nudity-topless', 'disturbing', 'thriller'],
#  [],
#  ['sequel'],
#  ['scifi', 'based-on-a-book', 'suspense', 'adapted-frombook'],
#  ['religion', 'bdr', 'clv', 'dvdvideo'],
#  [],
#  ['easily-confused-with-other-movies-title'],
#  ['music'],
#  ['sequel'],
#  ['nudity-topless', 'adapted-frombook'],
#  ['documentary', 'bdr'],
#  ['bad-acting',
#   'boring',
#   'not-funny',
#   'parody',
#   'satire',
#   'surreal',
#   'silly',
#   'less-than-300-ratings'],
#  [],
#  [],
#  [],
#  [],
#  ['nudity-topless-brief', 'nudity-topless', "tumey's-dvds"],
#  ['scifi', 'visually-appealing', 'tense', 'thriller'],
#  ['bdr'],
#  [],
#  ['murder', 'predictable'],
#  ['disturbing', 'social-commentary'],
#  [],
#  ["can't-remember", 'serial-killer', 'clv'],
#  ['aliens', 'friendship'],
#  ['adventure', 'comedy', 'funny', 'witty'],
#  ['betamax'],
#  ['sports',
#   'adapted-frombook',
#   'high-school',
#   'cinematography',
#   'drama',
#   'social-commentary',
#   'history'],
#  ['comedy', 'high-school', 'nudity-topless-notable', 'nudity-topless'],
#  ['bdr'],
#  ['based-on-a-book'],
#  [],
#  ['war', 'nudity-topless-brief', 'drama', 'mental-illness'],
#  ['netflix', "tumey's-dvds"],
#  ['documentary'],
#  [],
#  ['nudity-topless', 'bdr', 'dvdram'],
#  ['tense', 'based-on-a-book', 'betamax'],
#  ['bdr'],
#  ['boring', 'romance', 'hilarious'],
#  ['bdr', 'might-like'],
#  ['70mm', 'bdr', 'musical'],
#  ['bdr'],
#  ['less-than-300-ratings'],
#  ['nudity-topless', 'clearplay', 'r'],
#  [],
#  ["can't-remember"],
#  ['drugs', 'murder'],
#  ['betamax'],
#  ['criterion', 'movie-to-see', 'bdr', "erlend's-dvds", "tumey's-dvds"],
#  ['franchise', 'military', 'bad-acting', 'dvdvideo'],
#  ['nudity-full-frontal', 'campy', 'cult-film', 'boring'],
#  ['clv'],
#  ['betamax'],
#  ['funny'],
#  [],
#  ['dark-comedy',
#   'adapted-frombook',
#   'based-on-a-book',
#   'comedy',
#   'mental-illness'],
#  ['sports', 'boring'],
#  ['documentary'],
#  [],
#  ['suspense', 'dvd', "erlend's-dvds"],
#  ['revenge', 'remake', 'rape'],
#  ['boring', 'clearplay', 'r'],
#  ['clv'],
#  ['vhs', 'bdr'],
#  ['directorial-debut', 'scifi', 'thriller'],
#  ['animation', 'comedy', 'fatherson-relationship', 'action', 'violence'],
#  ['sports'],
#  ['nudity-topless', 'rape', 'revenge'],
#  [],
#  ['parody', 'comedy', 'hilarious'],
#  ['military'],
#  ['coming-of-age'],
#  ['funny', 'satire', 'betamax', 'reviewed', "tumey's-dvds"],
#  ['music'],
#  ['drama', 'dvd', 'boring', '70mm', 'anamorphic-blowup', 'clv', 'bibliothek'],
#  ['based-on-a-book', 'bdr', "tumey's-dvds"],
#  ['nudity-topless-notable', 'nudity-topless'],
#  ['less-than-300-ratings', '70mm', 'bdr'],
#  [],
#  ['surreal',
#   'remake',
#   'scifi',
#   'nudity-topless',
#   'fantasy',
#   'thriller',
#   'romance',
#   'new-york-city',
#   'stylized',
#   'seen-more-than-once'],
#  ['nudity-topless-brief',
#   'nudity-topless',
#   'new-york-city',
#   'true-story',
#   'boring',
#   'action',
#   'dvd'],
#  ['stylized', 'movie-to-see', 'seen-at-the-cinema'],
#  ['70mm', 'less-than-300-ratings'],
#  ['hilarious', 'comedy', 'romance', 'seen-at-the-cinema'],
#  ['murder', 'bdr', 'clv', 'bibliothek'],
#  ['sports', 'bdr'],
#  ['movie-to-see'],
#  ['animation',
#   'comedy',
#   'satire',
#   'parody',
#   'funny',
#   'witty',
#   'romance',
#   'quirky',
#   'based-on-a-book',
#   'seen-more-than-once',
#   'imdb-top-250'],
#  ['movie-to-see', 'hilarious', 'stupid', 'dvd', 'comedy'],
#  ["can't-remember"],
#  ['dvdram'],
#  ['politics', "can't-remember", 'funny', 'clv', 'comedy'],
#  ['70mm', 'anamorphic-blowup', 'clv'],
#  ['comedy', 'based-on-a-true-story', 'murder'],
#  [],
#  ['nudity-topless',
#   'based-on-a-true-story',
#   'true-story',
#   'nudity-topless-notable',
#   'england',
#   'drama',
#   'movie-to-see'],
#  ['classic',
#   'surreal',
#   'fantasy',
#   'cult-film',
#   'based-on-a-book',
#   'musical',
#   'witty',
#   'england',
#   'seen-more-than-once'],
#  ['revenge', 'comedy'],
#  ['easily-confused-with-other-movies-title', 'bdr', 'clv'],
#  ['disturbing', 'high-school', 'cinematography'],
#  ['bdr', 'might-like', "tumey's-dvds"],
#  ['might-like'],
#  ['scifi'],
#  ['criterion', 'bdr'],
#  ['nudity-topless', 'betamax'],
#  ['biography', 'drama', 'based-on-a-book', 'drugs'],
#  ['religion'],
#  ['police'],
#  ['scifi', 'suspense', 'bdr', 'dvdr', 'dvdram', 'might-like', "tumey's-dvds"],
#  ['scifi', 'coming-of-age', 'revenge', 'stupid', 'action', 'violence'],
#  [],
#  ['drugs'],
#  ['netflix',
#   'quirky',
#   'less-than-300-ratings',
#   'high-school',
#   'clearplay',
#   'r'],
#  ['rape'],
#  ['murder', 'less-than-300-ratings', 'bdr'],
#  ['visually-appealing', 'action', 'fantasy', 'cinematography'],
#  ['politics'],
#  ['dark',
#   'disturbing',
#   'atmospheric',
#   'surreal',
#   'quirky',
#   'nudity-full-frontal'],
#  ['nudity-topless'],
#  ['based-on-a-book', 'nudity-topless', 'world-war-ii'],
#  ['nudity-full-frontal', 'disturbing', 'directorial-debut'],
#  ['might-like'],
#  ['franchise'],
#  [],
#  ['less-than-300-ratings'],
#  ['campy', 'dvdr', 'dvdvideo'],
#  ['military', 'netflix', 'criterion', 'dvdvideo', 'vhs'],
#  ['humorous',
#   'nudity-topless',
#   'atmospheric',
#   'criterion',
#   'politics',
#   'dvdvideo',
#   "erlend's-dvds"],
#  ['less-than-300-ratings'],
#  ['action'],
#  ['adapted-frombook', 'based-on-a-book'],
#  ['violence', 'nudity-topless-brief', 'nudity-topless', 'surreal'],
#  ['might-like'],
#  ['might-like'],
#  ['not-funny', 'funny', 'bechdel-testpass'],
#  ['world-war-ii', 'imdb-top-250', "tumey's-dvds"],
#  ['horror', 'predictable', 'suspense', 'thriller', 'funny'],
#  ['family', 'adventure'],
#  ['scifi', 'franchise', 'aliens', 'seen-at-the-cinema'],
#  [],
#  [],
#  ['parody', 'police', 'betamax'],
#  ['nudity-topless', 'nudity-rear', 'r', 'netflix'],
#  ['70mm', 'anamorphic-blowup', 'bdr', 'clv', 'comedy', 'fantasy', 'musical'],
#  [],
#  ['police', 'comedy'],
#  ['bdr', 'clv'],
#  [],
#  ['seen-at-the-cinema'],
#  ['religion', 'history'],
#  ['comedy',
#   'funny',
#   'social-commentary',
#   'silly',
#   'predictable',
#   'parody',
#   'movie-to-see'],
#  ['bdr'],
#  ['adventure', 'predictable', 'action', 'bad-acting', 'dvd'],
#  [],
#  ['adapted-frombook', 'england', 'romance', 'based-on-a-book', 'bibliothek'],
#  ['military', "can't-remember", 'clv'],
#  ['bdr', 'betamax'],
#  ['cult-film', 'directorial-debut', 'clv'],
#  ['predictable', 'boring'],
#  ['bechdel-testpass'],
#  ['action', 'anamorphic-blowup', 'funny', 'sequel', '70mm', 'clv'],
#  ['franchise', 'dvdram', "erlend's-dvds"],
#  [],
#  ['drugs', 'crime', 'new-york-city', 'dark'],
#  ['friendship', 'crime'],
#  ['boring', 'silly', 'netflix'],
#  ['sports', 'action', 'drama', 'clv', 'franchise'],
#  ['nudity-topless',
#   'nudity-topless-notable',
#   'comedy',
#   'friendship',
#   'boring',
#   'clv'],
#  ['bdr', 'betamax'],
#  [],
#  ['remake', 'bibliothek', 'boring', 'seen-at-the-cinema'],
#  ['dvdr'],
#  ['betamax', 'dvdvideo'],
#  ['revenge', 'violence', 'fatherson-relationship', 'cinematography', 'boring'],
#  ['england',
#   'biography',
#   'history',
#   'true-story',
#   'religion',
#   'nudity-topless'],
#  [],
#  [],
#  ['adapted-frombook', 'world-war-ii', 'romance', 'based-on-a-book'],
#  ['bdr', 'clv', 'might-like'],
#  ['might-like'],
#  ['high-school', 'sports', 'nudity-topless'],
#  ['comedy',
#   'animation',
#   'sequel',
#   'bechdel-testfail',
#   'bechdel-testpass',
#   'reviewed'],
#  ['aliens'],
#  ['history', 'clearplay', 'r', 'drugs', 'music', 'violence'],
#  [],
#  ['based-on-a-book', 'adapted-frombook'],
#  ['bdr'],
#  ['bdr', 'to-see'],
#  ['family', 'betamax', 'clv'],
#  ['classic',
#   'atmospheric',
#   'humorous',
#   'imdb-top-250',
#   'drama',
#   'bdr',
#   'betamax'],
#  ['based-on-a-book', 'betamax', 'clv'],
#  ['predictable', 'coming-of-age', 'bechdel-testpass', 'animation'],
#  ['nudity-topless', 'documentary', 'music', 'new-york-city'],
#  ['funny', 'musical', 'nudity-topless', 'social-commentary'],
#  ['bibliothek'],
#  ['surreal'],
#  [],
#  ['religion', 'clv', 'dvdvideo'],
#  ['classic', 'war', 'romance', 'social-commentary', 'based-on-a-book'],
#  ['adapted-frombook', 'betamax'],
#  ['satire',
#   'comedy',
#   'cult-film',
#   'quirky',
#   'hilarious',
#   'revenge',
#   'dark-comedy',
#   'funny'],
#  ['less-than-300-ratings', 'bdr', 'clv', 'dvdr', "erlend's-dvds"],
#  [],
#  ['romance'],
#  ['bdr', 'dvdram', 'vhs'],
#  ['sports', 'seen-more-than-once'],
#  ['70mm', 'anamorphic-blowup'],
#  ['based-on-a-book'],
#  ['comedy', 'family', 'classic', 'new-york-city'],
#  ['less-than-300-ratings', 'serial-killer'],
#  ['drugs', 'clv', 'dvdvideo', 'to-see'],
#  ['bdr'],
#  ['documentary',
#   'sports',
#   'high-school',
#   'true-story',
#   'coming-of-age',
#   'social-commentary',
#   'movie-to-see',
#   'criterion',
#   'clv'],
#  ['humorous', 'comedy'],
#  ['action', "can't-remember", 'nudity-topless', 'revenge'],
#  ['bechdel-testfail', 'bdr'],
#  ['friendship', 'predictable', 'movie-to-see'],
#  ['nudity-topless-notable', 'nudity-topless', 'friendship', 'clv'],
#  ['bdr', 'dvdr'],
#  ['bdr'],
#  [],
#  ['high-school'],
#  ['action', 'scifi', 'based-on-a-book', 'bobola'],
#  ['clv'],
#  ['based-on-a-book'],
#  ['documentary', 'music'],
#  ['romance', 'sequel', 'quirky', 'boring'],
#  ['animation', 'bobola'],
#  ['coming-of-age'],
#  [],
#  ['atmospheric', 'criterion', 'tense', 'bdr', "tumey's-dvds"],
#  ['sports', 'surreal', 'might-like'],
#  ['true-story', 'action', 'crime', 'soundtrack', 'suspense'],
#  ['action', "can't-remember", 'clv'],
#  ['betamax'],
#  ['romance', 'bechdel-testfail', 'classic', 'comedy', 'bdr'],
#  ['nudity-topless-brief', 'based-on-a-book'],
#  ['murder'],
#  ['action', 'crime'],
#  ['adapted-frombook', 'bechdel-testfail'],
#  ['serial-killer', 'not-funny', 'horror'],
#  ['history', 'less-than-300-ratings', 'documentary', 'bdr', 'to-see'],
#  ['aliens', 'based-on-a-book', 'disturbing', 'stupid'],
#  ['coming-of-age'],
#  ['betamax', 'vhs'],
#  ['franchise', 'serial-killer'],
#  ['less-than-300-ratings'],
#  ['sports', 'documentary'],
#  ['atmospheric', 'music', 'cinematography', 'soundtrack', 'musical'],
#  ['parody', 'comedy', 'stupid', 'bobola', 'not-funny', 'horror'],
#  ['nudity-topless'],
#  ['dark', 'satire', 'social-commentary', 'bad-acting'],
#  [],
#  ['adapted-frombook', 'based-on-a-book', 'betamax', 'clv'],
#  ['campy'],
#  ['nudity-rear', 'nudity-topless-notable'],
#  ['betamax', 'fantasy'],
#  ['england', 'surreal'],
#  [],
#  [],
#  ['drama', 'less-than-300-ratings', 'thriller', 'england'],
#  ['nudity-topless', 'funny'],
#  ['war', 'funny', 'less-than-300-ratings', 'clearplay', 'r'],
#  [],
#  ['bad-acting'],
#  ['documentary', 'criterion', 'bdr'],
#  ['nudity-topless'],
#  ['new-york-city', 'r', 'clv', "erlend's-dvds"],
#  ['social-commentary'],
#  ['bdr'],
#  [],
#  ['soundtrack', 'classic'],
#  ['might-like'],
#  ['scifi', 'action', 'sequel', 'franchise', 'bad-acting'],
#  ['clv'],
#  ['romance', 'bechdel-testpass'],
#  ['remake', 'might-like'],
#  ['sports', 'coming-of-age', 'betamax', 'family'],
#  ['netflix', 'nudity-topless'],
#  ['atmospheric', 'coming-of-age', 'drama', 'family', 'horror', 'police'],
#  ['comedy',
#   'hilarious',
#   'nudity-topless',
#   'predictable',
#   'romance',
#   'nudity-topless-brief',
#   'drugs'],
#  ['world-war-ii', 'documentary'],
#  ['nudity-topless-notable', 'nudity-topless', 'dvdvideo'],
#  ['bdr'],
#  ['social-commentary'],
#  ['easily-confused-with-other-movies-title', 'betamax', 'dvdvideo'],
#  ['based-on-a-book', 'animation', 'betamax', 'vhs'],
#  ['bdr', 'dvdram'],
#  ['nudity-topless', 'police', 'drugs', 'comedy', 'hilarious', 'boring'],
#  ['dark-comedy', 'criterion', 'nudity-full-frontal', 'humorous'],
#  ['easily-confused-with-other-movies-title', 'action', 'clv'],
#  ['franchise', 'murder', 'serial-killer', 'nudity-topless', 'betamax'],
#  ['comedy', 'funny', "can't-remember", 'seen-at-the-cinema'],
#  ['betamax'],
#  ['history', 'politics', 'biography', 'cinematography', 'drama'],
#  ['movie-to-see', 'violence'],
#  [],
#  ['70mm', 'anamorphic-blowup', 'clv'],
#  ['betamax'],
#  ['bdr'],
#  ['dvdram'],
#  ['funny'],
#  ['thriller', 'clearplay', 'r'],
#  ['high-school', 'netflix'],
#  ['horror', 'tense', 'vhs', "erlend's-dvds"],
#  ['parody',
#   'hilarious',
#   'satire',
#   'comedy',
#   'witty',
#   'funny',
#   'religion',
#   'classic',
#   'cult-film',
#   'humorous',
#   'imdb-top-250'],
#  ['nudity-topless', 'nudity-full-frontal'],
#  ['70mm'],
#  ['funny'],
#  [],
#  ['nudity-topless-notable', 'directorial-debut', 'high-school'],
#  ['directorial-debut'],
#  ['betamax', 'clv'],
#  ['clv'],
#  ['funny', 'predictable', 'witty', 'comedy', 'action'],
#  ['betamax'],
#  ['based-on-a-book', 'religion'],
#  ['boring', 'new-york-city', 'funny'],
#  ['predictable', 'funny'],
#  ['music', 'new-york-city', 'dvdvideo'],
#  ["can't-remember", 'fantasy', 'comedy', 'romance'],
#  ["can't-remember"],
#  ['franchise', 'murder', 'seen-more-than-once', 'thriller', 'betamax', 'vhs'],
#  ['less-than-300-ratings'],
#  ['biography', 'true-story'],
#  ['adventure',
#   'friendship',
#   'predictable',
#   'funny',
#   'bechdel-testfail',
#   'fatherson-relationship',
#   'romance'],
#  ['dvdram'],
#  ['social-commentary', 'true-story', 'biography'],
#  ['predictable', 'funny', 'action', 'fatherson-relationship'],
#  ['netflix'],
#  ['classic', 'bdr'],
#  ['classic'],
#  ['mental-illness', 'documentary'],
#  ['scifi', 'aliens', 'suspense', 'atmospheric', 'action'],
#  [],
#  ['boring'],
#  ['less-than-300-ratings', 'bdr'],
#  ['nudity-topless'],
#  ['less-than-300-ratings', 'high-school', 'rape'],
#  ['less-than-300-ratings', 'atmospheric', 'bdr'],
#  ['biography', 'bobola', 'movie-to-see', 'clearplay', 'r'],
#  ['dvdvideo'],
#  ['less-than-300-ratings'],
#  ['based-on-a-book', 'nudity-rear', 'predictable'],
#  ['less-than-300-ratings'],
#  ['world-war-ii'],
#  ['scifi', 'drugs', 'dark-comedy'],
#  ['rape'],
#  [],
#  ['world-war-ii'],
#  ['nudity-topless'],
#  ['drama', "can't-remember", 'adapted-frombook', 'based-on-a-book', 'clv'],
#  ['nudity-topless'],
#  ['bdr', 'clv', 'dvdram'],
#  [],
#  ['betamax', 'dvdram'],
#  ['boring', 'visually-appealing', 'movie-to-see'],
#  ['boring', 'nudity-topless-notable', 'true-story', 'nudity-topless'],
#  ['funny'],
#  ['military'],
#  ['based-on-a-book', 'adapted-frombook', 'movie-to-see'],
#  ['documentary', 'true-story', 'funny', 'betamax', 'boring', 'music'],
#  [],
#  [],
#  ['less-than-300-ratings'],
#  ['visually-appealing',
#   'atmospheric',
#   'scifi',
#   'social-commentary',
#   'based-on-a-book',
#   'adapted-frombook',
#   'nudity-topless'],
#  ['netflix', 'remake', 'true-story', 'revenge', 'action', 'violence'],
#  ['new-york-city'],
#  ['romance', 'family', 'movie-to-see', 'not-funny'],
#  ['stylized', 'drugs', 'visually-appealing'],
#  ['high-school', 'nudity-topless-brief', 'based-on-a-book', 'r', 'clearplay'],
#  ['bad-acting', 'bdr', 'clv', 'dvdr'],
#  ['criterion',
#   'disturbing',
#   'drugs',
#   'based-on-a-book',
#   'betamax',
#   'nudity-topless',
#   'adapted-frombook',
#   'clv'],
#  [],
#  ['nudity-full-frontal', 'movie-to-see', 'slow', 'bibliothek'],
#  [],
#  ['nudity-topless', 'clv'],
#  [],
#  [],
#  ['clv', 'atmospheric', 'murder'],
#  ['less-than-300-ratings', 'surreal'],
#  ['music'],
#  ['bdr'],
#  ['criterion'],
#  ['nudity-full-frontal', "can't-remember", 'clv'],
#  ['satire', 'quirky', 'humorous', 'criterion'],
#  ['war'],
#  ['bdr'],
#  ['nudity-topless', 'england', 'clv'],
#  ['campy', 'humorous', 'cult-film', 'nudity-full-frontal'],
#  ['nudity-topless', 'dvdram'],
#  ['scifi',
#   'aliens',
#   'military',
#   'predictable',
#   'romance',
#   'war',
#   'politics',
#   'music'],
#  ['satire',
#   'aliens',
#   'scifi',
#   'witty',
#   'nudity-topless',
#   'social-commentary',
#   'military',
#   'based-on-a-book',
#   'campy',
#   'war',
#   'hilarious',
#   'funny',
#   'cult-film'],
#  ['nudity-topless'],
#  ['nudity-topless-notable',
#   'boring',
#   'action',
#   'politics',
#   'horror',
#   'scifi',
#   'nudity-topless',
#   'rape'],
#  ...]

# %%
mlb = MultiLabelBinarizer()
binary_labels = mlb.fit_transform(truncated_labels)
print("total number of unique tags: {} ".format(len(mlb.classes_)))

data = docs_df['plot'].values
indices = np.arange(len(data))
np.random.shuffle(indices)

data = [data[i] for i in indices]
targets = binary_labels[indices]
num_validation_samples = int(0.15 * len(data))

X_train = data[:-num_validation_samples]
Y_train = targets[:-num_validation_samples]
X_val = data[-num_validation_samples:]
Y_val = targets[-num_validation_samples:]

print('total number of train documents: {}'.format(len(X_train)))
print('total number of validation documents: {}'.format(len(X_val)))
# Out:
# total number of unique tags: 110
# total number of train documents: 1275
# total number of validation documents: 225

# %%
# good order (OVR just for the SVM, of course!)
pipeline = Pipeline([
    ('vect', CountVectorizer(max_features=MAX_NB_WORDS)),
    ('tfidf', TfidfTransformer()),
    ('clf', OneVsRestClassifier(LinearSVC(),n_jobs=-1)),
])

parameters = [
    { 
          "clf__estimator__penalty": ["l2"],
          "clf__estimator__dual":[False,True],
          "clf__estimator__multi_class":["crammer_singer","ovr"],
          "clf__estimator__tol": [0.001,0.0001],
          "vect__max_features": [MAX_NB_WORDS]  
    },
    { 
          "clf__estimator__penalty": ["l1"],
          "clf__estimator__dual":[False],
          "clf__estimator__multi_class":["crammer_singer","ovr"],
          "clf__estimator__tol": [0.001,0.0001],
          "vect__max_features": [MAX_NB_WORDS]  
    }    
]

# %%
best_score = float("-inf")

for g in ParameterGrid(parameters):
    pipeline.set_params(**g)
    
    pipeline.fit(X_train,Y_train)
    
    Y_pred_train = pipeline.predict(X_train)    
    Y_pred_val = pipeline.predict(X_val)
    
    train_score = f1_score(Y_train,Y_pred_train,average='micro')
    val_score = f1_score(Y_val,Y_pred_val,average='micro')
    
    current_score = val_score
    
    print("train micro-F1: {}".format(train_score))
    print("val micro-F1: {}".format(val_score))
    print("grid: {}".format(g))
    print("")
    
    if current_score > best_score:
        best_score = current_score
        best_grid = g
# Out:
# train micro-F1: 0.9987018606663781
# val micro-F1: 0.028328611898016998
# grid: {'clf__estimator__tol': 0.001, 'clf__estimator__dual': False, 'clf__estimator__penalty': 'l2', 'vect__max_features': 20000, 'clf__estimator__multi_class': 'crammer_singer'}
#
# train micro-F1: 0.9987018606663781
# val micro-F1: 0.028328611898016998
# grid: {'clf__estimator__tol': 0.0001, 'clf__estimator__dual': False, 'clf__estimator__penalty': 'l2', 'vect__max_features': 20000, 'clf__estimator__multi_class': 'crammer_singer'}
#
# train micro-F1: 0.9997118155619595
# val micro-F1: 0.0
# grid: {'clf__estimator__tol': 0.001, 'clf__estimator__dual': False, 'clf__estimator__penalty': 'l2', 'vect__max_features': 20000, 'clf__estimator__multi_class': 'ovr'}
#
# train micro-F1: 0.9997118155619595
# val micro-F1: 0.0
# grid: {'clf__estimator__tol': 0.0001, 'clf__estimator__dual': False, 'clf__estimator__penalty': 'l2', 'vect__max_features': 20000, 'clf__estimator__multi_class': 'ovr'}
#
# train micro-F1: 0.9987018606663781
# val micro-F1: 0.028328611898016998
# grid: {'clf__estimator__tol': 0.001, 'clf__estimator__dual': True, 'clf__estimator__penalty': 'l2', 'vect__max_features': 20000, 'clf__estimator__multi_class': 'crammer_singer'}
#
# train micro-F1: 0.9987018606663781
# val micro-F1: 0.028328611898016998
# grid: {'clf__estimator__tol': 0.0001, 'clf__estimator__dual': True, 'clf__estimator__penalty': 'l2', 'vect__max_features': 20000, 'clf__estimator__multi_class': 'crammer_singer'}
#
# train micro-F1: 0.9997118155619595
# val micro-F1: 0.0
# grid: {'clf__estimator__tol': 0.001, 'clf__estimator__dual': True, 'clf__estimator__penalty': 'l2', 'vect__max_features': 20000, 'clf__estimator__multi_class': 'ovr'}
#
# train micro-F1: 0.9997118155619595
# val micro-F1: 0.0
# grid: {'clf__estimator__tol': 0.0001, 'clf__estimator__dual': True, 'clf__estimator__penalty': 'l2', 'vect__max_features': 20000, 'clf__estimator__multi_class': 'ovr'}
#
# train micro-F1: 0.9987018606663781
# val micro-F1: 0.028328611898016998
# grid: {'clf__estimator__tol': 0.001, 'clf__estimator__dual': False, 'clf__estimator__penalty': 'l1', 'vect__max_features': 20000, 'clf__estimator__multi_class': 'crammer_singer'}
#
# train micro-F1: 0.9987018606663781
# val micro-F1: 0.028328611898016998
# grid: {'clf__estimator__tol': 0.0001, 'clf__estimator__dual': False, 'clf__estimator__penalty': 'l1', 'vect__max_features': 20000, 'clf__estimator__multi_class': 'crammer_singer'}
#
# train micro-F1: 0.32949087415946204
# val micro-F1: 0.0221606648199446
# grid: {'clf__estimator__tol': 0.001, 'clf__estimator__dual': False, 'clf__estimator__penalty': 'l1', 'vect__max_features': 20000, 'clf__estimator__multi_class': 'ovr'}
#
# train micro-F1: 0.32949087415946204
# val micro-F1: 0.0221606648199446
# grid: {'clf__estimator__tol': 0.0001, 'clf__estimator__dual': False, 'clf__estimator__penalty': 'l1', 'vect__max_features': 20000, 'clf__estimator__multi_class': 'ovr'}

# %%
print(best_score,best_grid)
# Out:
# 0.028328611898 {'clf__estimator__tol': 0.001, 'clf__estimator__dual': False, 'clf__estimator__penalty': 'l2', 'vect__max_features': 20000, 'clf__estimator__multi_class': 'crammer_singer'}
