# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import xml.etree.ElementTree as ET
import gc

from joblib import Parallel, delayed
from tqdm import *

# %matplotlib inline

# %%
ROOT = "/media/felipe/SAMSUNG/delicioust140/"

# %%
pd.__version__
# Out:
# '0.20.1'

# %%
FILE=ROOT+"taginfo.xml"

# %%
tree = ET.parse(FILE)

# %%
dataset = tree.getroot()

# %%
tags_df = pd.DataFrame(columns=['tag','count'])

# %%
def get_attribute_dict_from_document_node(document):
    attrs_dict = dict()
    
    for attribute_node in document:
                       
        tags = []
        
        if attribute_node.tag == 'tags':
            for tag_node in attribute_node:
                for subnode in tag_node:
                    if subnode.tag == 'name':
                        if subnode.text is not None:
                            tags.append(subnode.text)
                            
        
            attrs_dict['tags'] = ','.join(tags)              
                        
        else:
            attrs_dict[attribute_node.tag] = attribute_node.text
            
            
    return attrs_dict

# %%
elements = Parallel(n_jobs=-1)(delayed(get_attribute_dict_from_document_node)(document) for document in dataset)

# %%
docs_df = pd.DataFrame(columns=['url','hash','filetype','filename','users','tags'])

# %%
docs_df = pd.DataFrame.from_records(elements)

# %%
docs_df['num_tags'] = docs_df['tags'].apply(lambda tags: len(tags.split(',')))

# %%
docs_df.rename(columns={'users':'num_users'},inplace=True)

# %%
docs_df['num_users'] = docs_df['num_users'].astype('int64')
docs_df['num_tags'] = docs_df['num_tags'].astype('int64')

# %%
docs_df.describe(include=['number'])
# Out:
#            num_users       num_tags
# count  144574.000000  144574.000000
# mean      182.173109      13.950351
# std       663.709148       8.390065
# min         1.000000       1.000000
# 25%        13.000000       6.000000
# 50%        35.000000      12.000000
# 75%       121.000000      24.000000
# max     46215.000000      31.000000

# %%
docs_df.describe(include=['category','object'])
# Out:
#                                      filename filetype  \
# count                                  144574   144574
# unique                                 144574        5
# top     78f0d8cfae35f56be348a02e98b36a9f.html     html
# freq                                        1   143716
#
#                                     hash                    tags  \
# count                             144574                  144574
# unique                            144574                  144032
# top     d6a194b228ddd84cda253ac33ff8221d  wordpress,themes,theme
# freq                                   1                      15
#
#                               url
# count                      144574
# unique                     144574
# top     http://www.xchangeuk.com/
# freq                            1

# %%
docs_df.dtypes
# Out:
# filename     object
# filetype     object
# hash         object
# tags         object
# url          object
# num_users     int64
# num_tags      int64
# dtype: object

# %%
docs_df.sample(10)
# Out:
#                                      filename filetype  \
# 137786  d949616cb5645e6b2d877645bdb92f6d.html     html
# 51839   2c00dec317778bd95693f617727b3dcb.html     html
# 35608   d92e1ec143ab0c97e252feed17259324.html     html
# 130244  95f307e6cca487b505caafa28d623197.html     html
# 5789    0e1f977a1f69c836ab49efd59cfb5397.html     html
# 123578  5fd98471343dd50b8c071167a5fc2dc4.html     html
# 107700  047a1f413596c09e2cf2b409c057a700.html     html
# 114565  922ebdd241dd6a5e9f6bd90267d24f21.html     html
# 66140   e71d9f5bd9853a79132cd4a9078415bc.html     html
# 16728   6e8aef500b4cc01a048414f55258aba3.html     html
#
#                                     hash  \
# 137786  d949616cb5645e6b2d877645bdb92f6d
# 51839   2c00dec317778bd95693f617727b3dcb
# 35608   d92e1ec143ab0c97e252feed17259324
# 130244  95f307e6cca487b505caafa28d623197
# 5789    0e1f977a1f69c836ab49efd59cfb5397
# 123578  5fd98471343dd50b8c071167a5fc2dc4
# 107700  047a1f413596c09e2cf2b409c057a700
# 114565  922ebdd241dd6a5e9f6bd90267d24f21
# 66140   e71d9f5bd9853a79132cd4a9078415bc
# 16728   6e8aef500b4cc01a048414f55258aba3
#
#                                                      tags  \
# 137786                                recipes,food,recipe
# 51839   java,swing,programming,gui,mac,osx,native,wind...
# 35608   vintage,fashion,shopping,clothing,shoes,access...
# 130244  youtube,tools,video,web2.0,collection,videos,w...
# 5789    sewing,blog,blogs,crafts,crafty,craft,felt,han...
# 123578  food,indian,recipe,daal,recipes,cooking,dal,le...
# 107700  javascript,gallery,jquery,css,images,slideshow...
# 114565  git,tutorial,scm,versioncontrol,article,pdf,de...
# 66140   music,mp3,blog,mp3blog,vinyl,blogs,records,aud...
# 16728   geek,fashion,pants,keyboard,funny,technology,d...
#
#                                                       url  num_users  num_tags
# 137786  http://www.domesticgoddess.ca/recipes.php?reci...         11         3
# 51839   http://today.java.net/pub/a/today/2003/12/08/s...        106        23
# 35608            http://www.vivalavintage.com/index.shtml         16         6
# 130244  http://www.quickonlinetips.com/archives/2006/1...       1108        25
# 5789             http://www.cyncontemporary.blogspot.com/         12         8
# 123578               http://www.route79.com/food/daal.htm         56        11
# 107700                 http://code.google.com/p/galleria/        162        25
# 114565  http://www.newartisans.com/blog_files/git.from...        293        25
# 66140                       http://crudcrud.blogspot.com/        143        26
# 16728   http://www.vouspensez.com/2008/04/22/the-geeki...        141        25

# %%
docs_df[docs_df['num_users']<=2].sort_values('num_users')
# Out:
#                                      filename filetype  \
# 30571   9862166e802a18542e9f22be3b2b8dc4.html     html
# 139     01879557192bc8bcc69f78711aa580a1.html     html
# 92151   7e0ae721974661bd84f1d4e20464d33e.html     html
# 92142   e3230e1809a7d428b6a563afd6289df6.html     html
# 92047   3e35d090e633db29209444bd100fc3b8.html     html
# 92028   c0d40e4d854b1518cee6d261ce5fec04.html     html
# 92005   86138cb8d2008ba6b5970af9650000e7.html     html
# 91955   eabad7a90677ff1bedd138e5bbec5cf6.html     html
# 91915   fcab34a2e8c6055625c2915ac55c335e.html     html
# 91859   6a815f1b54c2f4c37629ea535fe64891.html     html
# 91818   356382fc9bd3991b156fccc7486fcd37.html     html
# 91801   44e9e8eb2fea2cf26b5d1f1ce58f953d.html     html
# 91753   4a462d97e86ebccfb56d776a4e79f3f9.html     html
# 91694   0c49fbfb113f99aee8bc5c8e7a7100d2.html     html
# 91678   41f1cd1cffe465bea7d9fe96221cd5c5.html     html
# 91674   607858a1622de2e5a8fd2d0ddf86544e.html     html
# 91511   6ce64f7ab248b9d1116d983596455e96.html     html
# 91384   aef31386da1616eb6e6ac8c65bcbd338.html     html
# 30571   flash,design,motorola,website,animation,microsite
# 139                         javascript,keyboard,shortcuts
# 92151                           health,tips,,loss,weight,
# 92142   online,rentals,condo,booking,hollywood,beach,v...
# 92047                  print,osx,freeware,server,printing
# 92028                             history,brain,evolution
# 92005                                 math,fractals,chaos
# 91955                     webdesign,inspiration,wordpress
# 91915   database,programming,java,tools,testing,unitte...
# 91859                                download,music,tools
# 91818                              download,video,youtube
# 91801                            programming,twitter,perl
# 91753                  politics,science,green,environment
# 91694                                  video,youtube,cpan
# 91678                       webdev,social,flex,portsmouth
# 91674   free,documentaries,lectures,lecture,news,biolo...
# 91511              technology,communication,entertainment
# 91384                          design,photography,graphic
# 91195                                 california,oil,fuel
# 90958                      download,mp3,rapidshare,albums
# 90846                                    ruby,barcode,pdf
# 90826                              cooking,recipe,walnuts
# 90817                                    green,home,yurts
# 90804                          indian,rice,hotels,recepie
# 90701                                 recipes,thai,shrimp
# 92179                                       flex,as3,amqp
# 92385      illustration,painting,calligraphy,illumination
# 92443                                 3d,c++,opengl,unimi
# 92455                 home,system,camera,surveillance,spy
# 95319                        library,education,librarians
# ...                                                   ...
# 48813                                     osx,php,eclipse
# 46356                           slash,bartleby/loki,dogma
# 46525                                       php,mysql,pdo
# 48763                               video,art,switzerland
# 48616                      social,game,play,participation
# 48416                                 reference,blog,pump
# 48372                      reference,free,tools,resources
# 48314                                recipes,dessert,cake
# 47959                    reference,maps,google,calculator
# 47934              tv,weird,aliens,paranormal,ghosts,yeti
# 47873                       video,blogging,birminghampost
# 47865                                review,sansa,sandisk
# 47846                                     audio,mp3,feeds
# 47763                         research,experience,blue_ng
# 47748   free,up,sign,bingo,uk,site,sites,online,review...
# 47723                         research,experience,blue_ng
# 47626                         research,experience,blue_ng
# 47608                                 space,3d,simulation
# 47454                                  linux,ip,configure
# 47423                    moblog,moblogging,mobileblogging
# 47350                            culture,business,mergers
# 47334                           food,architecture,housing
# 47271                                 python,cocoa,pyobjc
# 47234                                    mac,python,cocoa
# 47225                       software,opensource,portfolio
# 47056                               mobile,learning,phone
# 46792                               economics,economy,oil
# 46730   fashion,sewing,19thcentury,friends'sites,reena...
# 46370                            software,video,resources
# 144510                         technology,teaching,school
#
#                                                       url  num_users  num_tags
# 30571             http://www.soulpolice.com/motorolacity/          1         6
# 139                      http://livepipe.net/extra/hotkey          2         3
# 92151                  http://how-to-health.blogspot.com/          2         6
# 92142              http://hollywoodflvacationrentals.com/          2        12
# 92047   http://homepage.mac.com/barijaona/print66/pres...          2         5
# 92028   http://scienceblogs.com/neurophilosophy/2008/0...          2         3
# 92005   http://scienceblogs.com/goodmath/goodmath/topo...          2         3
# 91955                 http://scribblescratch.com/themes4/          2         3
# 91915        http://schemamule.sourceforge.net/index.html          2         6
# 91859                                http://sciagnik.net/          2         3
# 91818                               http://savevid.co.cc/          2         3
# 91801   http://search.cpan.org/~cthom/Net-Twitter-1.14...          2         3
# 144510  http://coe.west.asu.edu/students/nshamblin/tea...          2         3
#
# [1843 rows x 7 columns]

# %%
# number of documents by type

fig = plt.gcf()

fig.set_size_inches(15,10)

grouped = docs_df.groupby('filetype')['hash'].size()

print(grouped)

grouped.plot(kind='bar')
# Out:
# filetype
# html    143716
# pdf        424
# swf         75
# txt         94
# xml        265
# Name: hash, dtype: int64

# %%
# mean num_tags by type
docs_df.groupby('filetype')['num_tags'].mean().plot(kind='bar')

# %%
# mean num_users by type

grouped = docs_df.groupby('filetype')['num_users'].mean()

print(grouped)

grouped.plot(kind='bar')
# Out:
# filetype
# html    182.584750
# pdf      32.783019
# swf     245.893333
# txt      69.148936
# xml     220.011321
# Name: num_users, dtype: float64

# %%
max(set(docs_df['num_users'].values))
# Out:
# 46215

# %%
plt.clf()
docs_df.groupby('num_users').count()['hash'].sort_values(ascending=False).plot(kind='bar')

fig = plt.gcf()
fig.set_size_inches(18,5)

plt.gca().set_title('number of users per resource')
plt.gca().set_xlim(-1,100)
# Out:
# (-1, 100)

# %%
len(docs_df[docs_df['num_tags'] == 25])
# Out:
# 31511

# %%
docs_df.groupby('num_tags').count()['hash'].sort_values(ascending=False).plot(kind='bar')
plt.gca().set_title('number of tags per resource')
plt.gca().set_xlim(-1,30)
# Out:
# (-1, 30)

# %%
# total tags

tagsets = [tagset.split(',') for tagset in docs_df["tags"].values]

# %%
flat_list = []

for tagset in tagsets:
    for tag in tagset:
        flat_list.append(tag)
        
flat_set = set(flat_list)

# %%
len(flat_set)
# Out:
# 66023

# %%
sorted(flat_set)
# Out:
# ['',
#  '!',
#  '!!!',
#  '!!!financial',
#  '!!canoe',
#  '!important',
#  '!mp3',
#  '!music',
#  '!read.on',
#  '!songbird',
#  '#1',
#  '#develop',
#  '#due_south',
#  '$',
#  '$$$',
#  '$1',
#  '$10',
#  '$100',
#  '$20',
#  '$_server',
#  '$path',
#  '%s',
#  '&',
#  "'80s",
#  "'see'",
#  '(cam)',
#  '(design)',
#  '(firefly)',
#  '(fragmented)',
#  '(free)',
#  '(quando',
#  '(tony)',
#  '(x)html',
#  '*',
#  '**',
#  '***',
#  '****',
#  '*****',
#  '*articles',
#  '*audiovideo',
#  '*blog',
#  '*book',
#  '*box',
#  '*css',
#  '*design',
#  '*eightmedia',
#  '*firefox',
#  '*game',
#  '*hurt/comfort',
#  '*javascript',
#  '*life',
#  '*lifehack',
#  '*lifehacks',
#  '*mac',
#  '*n*x',
#  '*nix',
#  '*opera',
#  '*pc',
#  '*programming',
#  '*seoã\x83\x84ã\x83¼ã\x83«',
#  '*software',
#  '*tips',
#  '*to.read',
#  '*todo',
#  '*toread',
#  '*video',
#  '*web',
#  '*webdesign',
#  '*webservice',
#  '*webã\x82µã\x83¼ã\x83\x93ã\x82¹',
#  '*webå\x88¶ä½\x9c',
#  '*webç´\xa0æ\x9d\x90',
#  '*wordpress',
#  '*ã\x81¾ã\x81¨ã\x82\x81',
#  '*ã\x83\x97ã\x83\xadã\x82°ã\x83©ã\x83\x9fã\x83³ã\x82°',
#  '+',
#  '++',
#  '+2000words',
#  '+39',
#  '+5000words',
#  '+jobs',
#  '-',
#  '--',
#  '--operasoftware--',
#  '-1e',
#  '-2000words',
#  '-2e',
#  '-moz',
#  '...',
#  '.action',
#  '.bashrc',
#  '.bat',
#  '.com',
#  '.comresearch',
#  '.de',
#  '.deb',
#  '.dll',
#  '.ds_store',
#  '.emacs',
#  '.eu',
#  '.gov',
#  '.h',
#  '.htaccess',
#  '.htpasswd',
#  '.imported',
#  '.js.erb',
#  '.local',
#  '.mac',
#  '.mobi',
#  '.net',
#  '.net1.1',
#  '.net2',
#  '.net2.0',
#  '.net3',
#  '.net3.0',
#  '.net3.5',
#  '.net35',
#  '.netcf',
#  '.netforums',
#  '.netrocks',
#  '.nl',
#  '.org',
#  '.pl',
#  '.recipes',
#  '.rpm',
#  '.se',
#  '.search',
#  '.svn',
#  '.toread',
#  '.tv',
#  '.uk',
#  '/',
#  '//c',
#  '/3gb',
#  '/b/',
#  '/home',
#  '0%',
#  '0.01',
#  '0.9',
#  '000',
#  '000+',
#  '007',
#  '01100100',
#  '02',
#  '02138',
#  '08',
#  '0800',
#  '0822',
#  '0845',
#  '0870',
#  '08_doors/windows',
#  '08_hardware',
#  '09-05-07',
#  '09-finishes',
#  '0day',
#  '1',
#  '1%',
#  '1%rule',
#  '1-1',
#  '1-18-08',
#  '1-1s',
#  '1-800',
#  '1-to-1',
#  '1-wire',
#  '1.0',
#  '1.0.4',
#  '1.1',
#  '1.1.1',
#  '1.1.2',
#  '1.1.3',
#  '1.1.4',
#  '1.2',
#  '1.3',
#  '1.3.1',
#  '1.4',
#  '1.4.2',
#  '1.5',
#  '1.5.0',
#  '1.6',
#  '1.7',
#  '1.9',
#  '1.fm',
#  '10',
#  '10+',
#  '10-finger-system',
#  '10-specialties',
#  '10.1',
#  '10.4',
#  '10.5',
#  '10.5.1',
#  '10.5.2',
#  '10.5.3',
#  '10.6',
#  '100',
#  '100%',
#  '1000',
#  '1000_true_fans',
#  '1000journals',
#  '1000truefans',
#  '1001',
#  '1001cranes',
#  '100best',
#  '100chart',
#  '100e2r',
#  '100k',
#  '100khouse',
#  '100links',
#  '100shiki',
#  '100thingchallenge',
#  '100things',
#  '101',
#  '101cookbooks',
#  '101in1001',
#  '102',
#  '1020',
#  '103',
#  '103.1',
#  '1030',
#  '1058',
#  '1066',
#  '1074',
#  '1080p',
#  '1099',
#  '10am',
#  '10g',
#  '10k',
#  '10mins',
#  '10minutemail',
#  '10minutes',
#  '10questions',
#  '10th',
#  '10things',
#  '10x10',
#  '10ã\x81®ç\x90\x86ç\x94±',
#  '11',
#  '11-16',
#  '110',
#  '1130',
#  '11870',
#  '11ab',
#  '11g',
#  '12',
#  '120',
#  '1202',
#  '123',
#  '123di',
#  '128',
#  '12days',
#  '12ozmouse',
#  '12step',
#  '12steps',
#  '13',
#  '1337',
#  '1390',
#  '1394',
#  '14-19',
#  '1400',
#  '1401',
#  '1420',
#  '147',
#  '1471',
#  '1491',
#  '14valentines',
#  '15',
#  '1500',
#  '1501',
#  '1510',
#  '15daysofjquery',
#  '15daysofjquery.com',
#  '1600s',
#  '1626',
#  '163',
#  '168',
#  '16candlesverse',
#  '16f628',
#  '16thcentury',
#  '16x16',
#  '17',
#  '170',
#  '1775',
#  '17799',
#  '17thc',
#  '17thcentury',
#  '18',
#  '180',
#  '1800s',
#  '180photographers',
#  '18185',
#  '1828',
#  '1870',
#  '1896',
#  '18c',
#  '18eme',
#  '18seconds',
#  '18thc',
#  '18thcentury',
#  '1900',
#  '1900s',
#  '1911',
#  '192',
#  '1920',
#  '192021',
#  '1920s',
#  '1920x1200',
#  '1930',
#  '1930s',
#  '1940s',
#  '1948',
#  "1950's",
#  '1950s',
#  '1960',
#  '1960s',
#  '1963',
#  '1967',
#  '1968',
#  '1970',
#  '1970s',
#  '1975',
#  '1976',
#  '1976design',
#  '1977',
#  '1979',
#  '1980s',
#  '1983',
#  '1984',
#  '1989',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1999',
#  '19c',
#  '19th',
#  '19thc',
#  '19thcentury',
#  '1and1',
#  '1cd',
#  '1d',
#  '1dig',
#  '1indiannews',
#  '1kbwc',
#  '1oh1',
#  '1page',
#  '1password',
#  '1px',
#  '1series',
#  '1shotjunkie',
#  '1st',
#  '1stgrade',
#  '1tb',
#  '1to1',
#  '1u',
#  '1up',
#  '2',
#  '2-channel',
#  '2-column',
#  '2.0',
#  '2.0.1',
#  '2.01',
#  '2.1',
#  '2.3',
#  '2.4',
#  '2.46',
#  '2.5',
#  '2.6',
#  '2.6.24',
#  '2.x',
#  '20',
#  '20%',
#  '200',
#  '2000',
#  '2000ad',
#  '2001',
#  '2002',
#  '2003',
#  '2003_server',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2007-08-08',
#  '20070115',
#  '20070225',
#  '20071216',
#  '2007peno1milieu',
#  '2007ref',
#  '2007w',
#  '2008',
#  '200803',
#  '20080602',
#  '2008election',
#  '2008å\x85\xadæ\x9c\x88',
#  '2009',
#  '201',
#  '2010',
#  '2012',
#  '2015',
#  '2030',
#  '2032',
#  '2038',
#  '2057',
#  '2072',
#  '2073',
#  '2085',
#  '20bits',
#  '20d',
#  '20g',
#  '20s',
#  '20six',
#  '20th',
#  '20th_century',
#  '20thcentury',
#  '20thcenturyvole',
#  '21',
#  '2100',
#  '212',
#  '212box',
#  '212degrees',
#  '213',
#  '2133',
#  '2138',
#  '21apples',
#  '21centuryskills',
#  '21cliteracy',
#  '21literacy',
#  '21st',
#  '21st_century',
#  '21st_century_learning',
#  '21st_century_skills',
#  '21stcentury',
#  '21stcenturyclassroom',
#  '21stcenturylearners',
#  '21stcenturylearning',
#  '21stcenturyskills',
#  '22',
#  '2200bg',
#  '221b',
#  '226bw',
#  '22pixels',
#  '23',
#  '23/6',
#  '236',
#  '23_things',
#  '23andme',
#  '23asiaa',
#  '23dingen',
#  '23pasos',
#  '23things',
#  '23thingsonastick',
#  '24',
#  '24/7',
#  '240',
#  '2416',
#  '24c3',
#  '24p',
#  '24ways',
#  '25',
#  '250.221',
#  '253',
#  '2600',
#  '2600n',
#  '26things',
#  '27001',
#  '28',
#  '2812',
#  '2828',
#  '2853',
#  '2881',
#  '2899',
#  '28hourday',
#  '2923',
#  '2950',
#  '2advanced',
#  '2bbs',
#  '2buy',
#  '2ch',
#  '2chan',
#  '2channel',
#  '2check',
#  '2column',
#  '2d',
#  '2d-code',
#  '2d-codes',
#  '2dcode',
#  '2dl',
#  '2do',
#  '2do.diy',
#  '2download',
#  '2ehands',
#  '2gether08',
#  '2girls1cup',
#  '2k3',
#  '2l',
#  '2meter',
#  '2nd',
#  '2nd_grade',
#  '2ndgrade',
#  '2ndlife',
#  '2ndmath-q1',
#  '2ndskin',
#  '2ndwave',
#  '2pc',
#  '2people',
#  '2pointhome',
#  '2read',
#  '2sort',
#  '2watch',
#  '2wire',
#  '2x13',
#  '2x2',
#  '2x4',
#  '2x5',
#  '2xexplorer',
#  '3',
#  '3-5',
#  '3-6',
#  '3-column',
#  '3-d',
#  '3-g',
#  '3-tier',
#  '3-way',
#  '3.0',
#  '3.3',
#  '3.4',
#  '3.5',
#  '30',
#  '300',
#  '3000',
#  '301',
#  '301-redirect',
#  '301redirect',
#  '301redirects',
#  '302',
#  '303',
#  '3066',
#  '30boxes',
#  '30daychallenge',
#  '30days',
#  '30dc',
#  '30gb',
#  '30s',
#  '311',
#  '3110',
#  '3166',
#  '32',
#  '32-bit',
#  '320',
#  '3270',
#  '32bit',
#  '3338',
#  '33mins',
#  '3401',
#  '345',
#  '3459',
#  '350',
#  '350d',
#  '3574',
#  '35mm',
#  '360',
#  '360buy',
#  '360desktop',
#  '360Â°',
#  '3649',
#  '365',
#  '365libs',
#  '3744',
#  '3790',
#  '37s',
#  '37signals',
#  '3805',
#  '3852',
#  '3866',
#  '3945',
#  '3945abg',
#  '3b',
#  '3c',
#  '3ccd',
#  '3col',
#  '3column',
#  '3com',
#  '3cst3',
#  '3d',
#  '3d-modeling',
#  '3d-models',
#  '3d-tv',
#  '3d_models',
#  '3d_printing',
#  '3d_studio_max',
#  '3d_tutorials',
#  '3dbox',
#  '3dcg',
#  '3dengine',
#  '3des',
#  '3dgamestudio',
#  '3dgis',
#  '3dgraphics',
#  '3dmark06',
#  '3dmax',
#  '3dmodel',
#  '3dmodeling',
#  '3dmodels',
#  '3dpdf',
#  '3dprinter',
#  '3dprinting',
#  '3drendering',
#  '3ds',
#  '3dscanner',
#  '3dscanning',
#  '3dshape',
#  '3dshapes',
#  '3dsm',
#  '3dsmax',
#  '3dspecialfx',
#  '3dstroke',
#  '3dstuff',
#  '3dstut',
#  '3dtext',
#  '3dtextmaker',
#  '3dtutorial',
#  '3dui',
#  '3dvia',
#  '3g',
#  '3gb',
#  '3gp',
#  '3gpp',
#  '3gsm',
#  '3ivx',
#  '3jam',
#  '3jane',
#  '3k',
#  '3l',
#  '3m',
#  '3nf',
#  '3px',
#  '3rd',
#  '3rd-grade',
#  '3rd_grade',
#  '3rd_leg',
#  '3rdgrade',
#  '3rdparty',
#  '3rvx',
#  '3some',
#  '3store',
#  '3ware',
#  '3wheeler',
#  '3wheelers',
#  '3x3',
#  '3x5',
#  '3ã\x82\xadã\x83£ã\x83ªã\x82¢',
#  '4',
#  '4-6numbers',
#  '4-6statistics',
#  '4-8',
#  '4-hour',
#  '4-q1',
#  '4.0',
#  '4.01',
#  '4.1',
#  '4/3',
#  '40',
#  '40+',
#  '400',
#  '40000',
#  '4004',
#  '400d',
#  '400project',
#  '401',
#  '401(k)',
#  '401.1',
#  '401k',
#  '4024',
#  '4035',
#  '404',
#  '405',
#  '4094',
#  '40d',
#  '40k',
#  '40s',
#  '411',
#  '419',
#  '42',
#  '420',
#  '421',
#  '4222',
#  '4226',
#  '422notes',
#  '43',
#  '43-folders',
#  '430ex',
#  '43_things',
#  '43f',
#  '43folders',
#  '43places',
#  '43things',
#  '4401',
#  '44pin',
#  '450d',
#  '456',
#  '458work',
#  '460616',
#  '480',
#  '4815162342',
#  '486',
#  '4965agn',
#  '4blocks',
#  '4chan',
#  '4ct',
#  '4d',
#  '4dos',
#  '4e',
#  '4ewriting',
#  '4fuzzyplans',
#  '4g',
#  '4gb',
#  '4guys',
#  '4guysfromrolla',
#  '4gw',
#  '4hero',
#  '4hour',
#  '4hourweek',
#  '4hourworkweek',
#  '4hww',
#  '4info',
#  '4ip',
#  '4k',
#  '4kids',
#  '4life',
#  '4mat',
#  '4nt',
#  '4od',
#  '4operations',
#  '4q',
#  '4shared',
#  '4slate',
#  '4suite',
#  '4teachers',
#  '4th',
#  '4th-grade',
#  '4th_grade',
#  '4thedition',
#  '4thgrade',
#  '4work',
#  '4x',
#  '4x5',
#  '5',
#  '5%',
#  '5-07',
#  '5-8',
#  '5-gram',
#  '5.0',
#  '5.1',
#  '5.2',
#  '5.3',
#  '5.5',
#  '5/3',
#  '5/5',
#  '50',
#  "50's",
#  '50+',
#  '500',
#  '5007eg',
#  '500gb',
#  '504plan',
#  '505',
#  '508',
#  '50best',
#  '50cent',
#  '50ft',
#  '50mm',
#  '50s',
#  '51',
#  '51job',
#  '52',
#  '5200',
#  '521',
#  '527s',
#  '529',
#  '529plans',
#  '53',
#  '5400',
#  '5411',
#  '55-200',
#  '550',
#  '555',
#  '570',
#  '5710',
#  '580ex',
#  '58ninety',
#  '58ninety-account',
#  '5d',
#  '5es',
#  '5fm',
#  '5ives',
#  '5k',
#  '5live',
#  '5min',
#  '5pm',
#  '5stagemodel',
#  '5star',
#  '5th',
#  '5th_grade',
#  '5thgrade',
#  '5things',
#  '5weeks',
#  '5whys',
#  '5x5',
#  '5x5x5',
#  '6',
#  '6+1',
#  '6+1_writing',
#  '6+1trait',
#  '6+1traits',
#  '6-12',
#  '6-8',
#  '6-traits',
#  '6.0',
#  '6.06',
#  '6.1',
#  '6.170',
#  '60',
#  "60's",
#  '600',
#  '6008',
#  '605',
#  '60fps',
#  '60frames',
#  '60minutes',
#  '60mpg',
#  '60s',
#  '6120c',
#  '616',
#  '6300',
#  '64',
#  '64-bit',
#  '64bit',
#  '64bits',
#  '64k',
#  '650',
#  '6500',
#  '6582',
#  '65daysofstatic',
#  '6600',
#  '6680',
#  '6700',
#  '677',
#  '68',
#  '6800',
#  '68k',
#  '6_traits_of_writing',
#  '6_traits_writing',
#  '6degrees',
#  '6music',
#  '6park',
#  '6th',
#  '6th_grade',
#  '6trait',
#  '6traits',
#  '7',
#  '7-zip',
#  '7.0',
#  '7.04',
#  '7.10',
#  "70's",
#  '70-536',
#  '700wx',
#  '705nk',
#  '70s',
#  '7200',
#  '720p',
#  '7250',
#  '741',
#  '75',
#  '756',
#  '76design-research',
#  '77',
#  '770',
#  '78rpm',
#  '798',
#  '7habits',
#  '7layer',
#  '7principles',
#  '7th',
#  '7things',
#  '7up',
#  '7z',
#  '7zip',
#  '8',
#  '8-bit',
#  '8-ict',
#  '8.0',
#  '8.04',
#  '8.2',
#  '80',
#  "80's",
#  '80-20',
#  '80/20',
#  '800',
#  '802.11',
#  '802.11n',
#  '802.1x',
#  '802.20',
#  '8020',
#  '8051',
#  '808',
#  '80gb',
#  '80s',
#  '80x15',
#  '80x86',
#  '80Â´s',
#  '8100',
#  '810f',
#  '8125',
#  '8250',
#  '826',
#  '8525',
#  '855',
#  '8601',
#  '870',
#  '8830',
#  '89',
#  '89.3',
#  '8925',
#  '8bit',
#  '8box',
#  '8hands',
#  '8mm',
#  '9',
#  '9-11',
#  '9-12',
#  '9-1group5',
#  '9-1group7',
#  '9-2group2',
#  '9.2',
#  '9.5',
#  '9/11',
#  '9000',
#  '901',
#  '909',
#  '90s',
#  '911',
#  '9126',
#  '9300',
#  '94',
#  '960',
#  '96kb',
#  '96maygrove',
#  '98',
#  '987mb',
#  '99',
#  '990',
#  '9egeometrie',
#  '9i',
#  '9p',
#  '9rules',
#  '9x9',
#  '=blog',
#  '=cool',
#  '=research',
#  '=resource',
#  '?',
#  '??',
#  '@_to_read',
#  '@books',
#  '@brass_crescent',
#  '@check_the_site',
#  '@daily',
#  '@firefox',
#  '@google',
#  '@home',
#  '@import',
#  '@media',
#  '@merlib.org',
#  '@my.computer',
#  '@read',
#  '@reading',
#  '@replies',
#  '@review',
#  '@todo',
#  '@tools',
#  '@toread',
#  '@videos',
#  '@wikipedia',
#  '@work',
#  '[3jane]',
#  '[clumsygyrl]',
#  '[de]',
#  '[en]',
#  '[enoughoflove]',
#  '[fr]',
#  '[jayne.cobb]',
#  '[jp]',
#  '[kr]',
#  '[pg]',
#  '[pl]',
#  '[sga]',
#  '[simon.tam]',
#  '[thingsyoumissed]',
#  '[thirdonebetween]',
#  ...]
