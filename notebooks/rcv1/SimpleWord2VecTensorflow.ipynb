# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import random
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf
from tensorflow.python.client import device_lib

# %matplotlib inline

# %%
local_device_protos = device_lib.list_local_devices()
[x.name for x in local_device_protos if x.device_type == 'GPU']
# Out:
# ['/gpu:0']

# %%
path_to_data="../../data/text8/text8"

with open(path_to_data) as f:
    words = tf.compat.as_str(f.read()).split()

# %%
print('Data size', len(words))
# Out:
# Data size 17005207

# %%
# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()

    for word, _ in count:
        dictionary[word] = len(dictionary)
  
    data = list()
    unk_count = 0
  
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count += 1
        data.append(index)
    
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    
    return data, count, dictionary, reverse_dictionary

# %%
data, count, dictionary, reverse_dictionary = build_dataset(words)
del words  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5237, 3082, 12, 6, 195, 2, 3134, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
  
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
  
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [skip_window]
    
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
           
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
            
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
        
    return batch, labels

# %%
batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
    print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 3082 originated -> 12 as
# 3082 originated -> 5237 anarchism
# 12 as -> 6 a
# 12 as -> 3082 originated
# 6 a -> 12 as
# 6 a -> 195 term
# 195 term -> 6 a
# 195 term -> 2 of

# %%
# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.

# %%
# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64    # Number of negative examples to sample.

# %%
graph = tf.Graph()

# %%
with graph.as_default():

    # Input data.
    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Ops and variables pinned to the CPU because of missing GPU implementation
    with tf.device('/cpu:0'):
        # Look up embeddings for inputs.
        embeddings = tf.Variable(
            tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
        embed = tf.nn.embedding_lookup(embeddings, train_inputs)

        # Construct the variables for the NCE loss
        nce_weights = tf.Variable(
            tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
        nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

        # Compute the average NCE loss for the batch.
        # tf.nce_loss automatically draws a new sample of the negative labels each
        # time we evaluate the loss.
    loss = tf.reduce_mean(
        tf.nn.nce_loss(weights=nce_weights,
                         biases=nce_biases,
                         labels=train_labels,
                         inputs=embed,
                         num_sampled=num_sampled,
                         num_classes=vocabulary_size))

    # Construct the SGD optimizer using a learning rate of 1.0.
    optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

    # Compute the cosine similarity between minibatch examples and all embeddings.
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(
        valid_embeddings, normalized_embeddings, transpose_b=True)

    # Add variable initializer.
    init = tf.initialize_all_variables()

# %%
# Step 5: Begin training.
num_steps = 100001

# %%
with tf.Session(graph=graph) as session:
    # We must initialize all variables before we use them.
    init.run()
    print("Initialized")

    average_loss = 0
    for step in xrange(num_steps):
        batch_inputs, batch_labels = generate_batch(
            batch_size, num_skips, skip_window)
        feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

        # We perform one update step by evaluating the optimizer op (including it
        # in the list of returned values for session.run()
        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val

        if step % 2000 == 0:
            if step > 0:
                average_loss /= 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print("Average loss at step ", step, ": ", average_loss)
            average_loss = 0

        # Note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in xrange(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log_str = "Nearest to %s:" % valid_word
                for k in xrange(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = "%s %s," % (log_str, close_word)
                print(log_str)
                
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  289.693267822
# Nearest to or: backdrop, patagonian, hyderabad, farmers, powers, jamison, mcpherson, overridden,
# Nearest to three: agility, norman, trigger, stirling, yan, leno, sennett, evangelista,
# Nearest to its: swiftly, fyrom, ferrol, hz, fireworks, verse, guantanamo, brentano,
# Nearest to during: rojas, called, lex, lasts, sunk, procession, episodes, peek,
# Nearest to not: decomposers, rays, thom, aquaculture, capricornus, zr, exposes, kabul,
# Nearest to state: budapest, advancement, cathal, newington, accumulator, kayaks, auditory, malicious,
# Nearest to six: rehearsed, alene, barnett, commando, ning, protectionist, propel, craton,
# Nearest to at: toby, besieging, ascendant, flavian, suras, mausoleum, ascetical, buggy,
# Nearest to some: leyte, gormenghast, trench, bracelet, ignored, howl, safeguard, atp,
# Nearest to than: ezquerra, retake, regicide, implicit, lepton, egress, youngsters, topology,
# Nearest to known: villages, compressing, stings, mulholland, highest, soundness, vogel, belongings,
# Nearest to time: harbours, flickr, abreast, cana, hub, galbraith, overriding, alexandrine,
# Nearest to these: appears, expanse, jockeys, hamper, wimp, every, piloted, wormhole,
# Nearest to between: quantrill, pictured, weinberg, octopus, lepton, mastermind, renfrew, exactly,
# Nearest to that: dismemberment, concert, noticing, hines, the, rabban, slump, astrakhan,
# Nearest to united: travelers, tautologies, modifiers, because, heartbeat, watches, atlantean, pertains,
# Average loss at step  2000 :  114.861605762
# Average loss at step  4000 :  52.6316247282
# Average loss at step  6000 :  33.2840242219
# Average loss at step  8000 :  23.7980303211
# Average loss at step  10000 :  17.0454079427
# Nearest to or: and, backdrop, farmers, zero, in, s, rho, avatar,
# Nearest to three: one, cc, nine, zero, dione, and, dong, yan,
# Nearest to its: the, inhibition, color, brentano, servants, album, vi, awaiting,
# Nearest to during: called, one, episodes, pendulum, in, aztec, procession, utility,
# Nearest to not: kabul, daughters, people, relative, female, eight, notable, track,
# Nearest to state: john, budapest, advancement, theorem, compositing, foreground, out, banjo,
# Nearest to six: nine, eight, zero, rho, five, loan, grids, seven,
# Nearest to at: and, olympian, with, of, glass, in, communicating, robin,
# Nearest to some: dienes, euphoria, vector, christ, mechanics, broadcasting, druidry, kwh,
# Nearest to than: topology, manuscripts, nine, rainy, implicit, and, bastille, textrm,
# Nearest to known: rho, villages, highest, danish, more, cat, darker, circumference,
# Nearest to time: dragon, harbours, humanity, ought, w, inhibition, matter, cc,
# Nearest to these: appears, five, that, association, every, dong, biomes, mini,
# Nearest to between: in, pictured, dragoons, inhibition, with, exactly, investigator, incarnation,
# Nearest to that: inhibition, also, and, sl, avatar, these, napoleonic, superheroes,
# Nearest to united: because, copies, modifiers, observer, fault, banjo, ki, dice,
# Average loss at step  12000 :  13.5553343403
# Average loss at step  14000 :  11.4544442495
# Average loss at step  16000 :  10.0300460303
# Average loss at step  18000 :  8.552867149
# Average loss at step  20000 :  8.07901475918
# Nearest to or: and, s, backdrop, falsehood, UNK, with, rho, cc,
# Nearest to three: zero, two, one, eight, five, seven, six, nine,
# Nearest to its: the, his, inhibition, color, a, servants, cl, zeus,
# Nearest to during: in, called, episodes, bugs, pendulum, aztec, eloquence, trinidad,
# Nearest to not: they, exposes, it, kabul, fac, to, priscilla, eight,
# Nearest to state: advancement, budapest, vanunu, john, pyramid, telecom, eml, uninterested,
# Nearest to six: nine, eight, zero, five, seven, three, one, two,
# Nearest to at: in, and, of, with, olympian, for, senseless, glass,
# Nearest to some: parl, serbo, eigenstates, dienes, royalists, webster, kwh, mechanics,
# Nearest to than: and, manuscripts, or, topology, regicide, implicit, bastille, rainy,
# Nearest to known: villages, rho, jurisdictions, more, highest, cat, hopi, danish,
# Nearest to time: flickr, dragon, cadet, humanity, atomic, magnetic, declaration, harbours,
# Nearest to these: appears, that, dong, all, widehat, equipment, every, five,
# Nearest to between: in, with, pictured, dragoons, weinberg, inhibition, microstates, and,
# Nearest to that: which, inhibition, also, prone, these, luncheon, widehat, now,
# Nearest to united: andree, copies, modifiers, because, lacks, travelers, fault, observer,
# Average loss at step  22000 :  7.43933770168
# Average loss at step  24000 :  6.8635505259
# Average loss at step  26000 :  6.36771369946
# Average loss at step  28000 :  6.20488924623
# Average loss at step  30000 :  6.18063959038
# Nearest to or: and, neutronic, kiang, quagga, zero, six, s, eight,
# Nearest to three: four, five, two, six, seven, eight, one, nine,
# Nearest to its: the, his, their, inhibition, quagga, servants, color, a,
# Nearest to during: in, neutronic, bugs, kiang, is, episodes, pendulum, aztec,
# Nearest to not: it, they, exposes, kabul, who, to, neutronic, only,
# Nearest to state: advancement, budapest, vanunu, phenomenal, bytecode, gains, telecom, tobruk,
# Nearest to six: eight, nine, five, four, seven, three, zero, two,
# Nearest to at: in, with, olympian, four, after, and, quagga, for,
# Nearest to some: parl, kiang, the, eigenstates, serbo, webster, royalists, dienes,
# Nearest to than: and, or, freya, neutronic, regicide, retake, manuscripts, kiang,
# Nearest to known: villages, jurisdictions, more, lyndon, rho, cat, getter, darker,
# Nearest to time: flickr, cadet, atomic, humanity, quagga, domo, efficiencies, declaration,
# Nearest to these: all, equipment, the, widehat, five, galesburg, mini, dong,
# Nearest to between: with, in, pictured, dragoons, quagga, weinberg, neutronic, recited,
# Nearest to that: which, inhibition, kiang, neutronic, also, quagga, akhenaten, it,
# Nearest to united: andree, modifiers, lacks, copies, neutronic, travelers, banjo, fault,
# Average loss at step  32000 :  5.8347734679
# Average loss at step  34000 :  5.72507145
# Average loss at step  36000 :  6.10317496991
# Average loss at step  38000 :  5.50857246792
# Average loss at step  40000 :  5.47805231905
# Nearest to or: and, neutronic, kiang, quagga, arctocephalus, for, than, zero,
# Nearest to three: four, two, five, six, seven, eight, one, zero,
# Nearest to its: the, their, his, inhibition, quagga, servants, color, doubled,
# Nearest to during: in, neutronic, arctocephalus, kiang, bugs, on, episodes, between,
# Nearest to not: it, they, arctocephalus, to, exposes, who, kabul, also,
# Nearest to state: advancement, budapest, vanunu, phenomenal, bytecode, tobruk, telecom, gains,
# Nearest to six: eight, seven, five, nine, four, three, zero, two,
# Nearest to at: in, olympian, with, after, quagga, arctocephalus, neutronic, for,
# Nearest to some: many, the, parl, serbo, kiang, webster, eigenstates, these,
# Nearest to than: or, and, freya, neutronic, regicide, retake, manuscripts, defamation,
# Nearest to known: jurisdictions, villages, lyndon, rho, getter, oppression, such, wonderful,
# Nearest to time: flickr, abreast, atomic, efficiencies, quagga, domo, mvs, humanity,
# Nearest to these: all, some, equipment, widehat, three, galesburg, slits, two,
# Nearest to between: with, in, dragoons, pictured, quagga, weinberg, during, neutronic,
# Nearest to that: which, inhibition, it, arctocephalus, akhenaten, this, kiang, neutronic,
# Nearest to united: tetra, andree, lacks, modifiers, neutronic, travelers, copies, tautologies,
# Average loss at step  42000 :  5.33421930683
# Average loss at step  44000 :  5.04166889334
# Average loss at step  46000 :  5.23188898456
# Average loss at step  48000 :  5.30781632856
# Average loss at step  50000 :  5.24780226183
# Nearest to or: and, stadtbahn, quagga, neutronic, arctocephalus, kiang, six, three,
# Nearest to three: four, five, two, six, seven, eight, zero, stadtbahn,
# Nearest to its: their, the, his, inhibition, quagga, kiang, servants, zeus,
# Nearest to during: in, on, stadtbahn, neutronic, arctocephalus, kiang, from, bugs,
# Nearest to not: it, they, arctocephalus, to, usually, only, exposes, still,
# Nearest to state: advancement, budapest, vanunu, pyramid, bytecode, phenomenal, telecom, tobruk,
# Nearest to six: seven, five, eight, four, three, nine, zero, two,
# Nearest to at: in, olympian, after, with, on, quagga, lagenorhynchus, arctocephalus,
# Nearest to some: many, these, kiang, parl, webster, eigenstates, the, serbo,
# Nearest to than: or, and, freya, neutronic, regicide, defamation, retake, manuscripts,
# Nearest to known: jurisdictions, villages, such, lyndon, rho, oppression, part, getter,
# Nearest to time: atomic, flickr, efficiencies, eoka, eider, abreast, domo, twenties,
# Nearest to these: some, all, many, stadtbahn, widehat, equipment, three, they,
# Nearest to between: with, in, dragoons, pictured, on, valine, during, weinberg,
# Nearest to that: which, inhibition, stadtbahn, this, however, kiang, arctocephalus, quagga,
# Nearest to united: tetra, andree, lacks, modifiers, travelers, tautologies, neutronic, bananas,
# Average loss at step  52000 :  5.24233269751
# Average loss at step  54000 :  5.03639397085
# Average loss at step  56000 :  5.08657758796
# Average loss at step  58000 :  4.85240486038
# Average loss at step  60000 :  4.91324139178
# Nearest to or: and, neutronic, stadtbahn, quagga, arctocephalus, than, kiang, but,
# Nearest to three: four, five, six, two, eight, seven, one, stadtbahn,
# Nearest to its: their, the, his, inhibition, quagga, kiang, servants, her,
# Nearest to during: in, neutronic, rium, stadtbahn, arctocephalus, from, kiang, on,
# Nearest to not: it, they, arctocephalus, only, still, usually, be, kabul,
# Nearest to state: advancement, budapest, vanunu, bytecode, history, tobruk, pyramid, banjo,
# Nearest to six: five, seven, eight, four, nine, three, zero, two,
# Nearest to at: in, olympian, after, quagga, with, arctocephalus, stadtbahn, on,
# Nearest to some: many, these, the, webster, kiang, parl, eigenstates, royalists,
# Nearest to than: or, neutronic, regicide, nine, freya, and, pebble, manuscripts,
# Nearest to known: such, jurisdictions, used, lyndon, villages, part, oppression, rho,
# Nearest to time: atomic, eider, flickr, domo, quagga, eoka, efficiencies, year,
# Nearest to these: some, all, many, equipment, they, such, widehat, stadtbahn,
# Nearest to between: with, in, dragoons, valine, seven, pictured, quagga, during,
# Nearest to that: which, this, inhibition, stadtbahn, however, galatea, arctocephalus, also,
# Nearest to united: tetra, lacks, andree, modifiers, travelers, neutronic, galatea, tautologies,
# Average loss at step  62000 :  5.03203855765
# Average loss at step  64000 :  4.87118433142
# Average loss at step  66000 :  4.90756588745
# Average loss at step  68000 :  4.92515080464
# Average loss at step  70000 :  4.85480139351
# Nearest to or: and, landesverband, than, hyi, neutronic, stadtbahn, ebne, quagga,
# Nearest to three: four, five, six, two, eight, seven, zero, nine,
# Nearest to its: their, his, the, ebne, inhibition, kiang, servants, quagga,
# Nearest to during: in, stadtbahn, neutronic, from, arctocephalus, rium, landesverband, at,
# Nearest to not: they, it, arctocephalus, still, be, usually, to, kiang,
# Nearest to state: advancement, budapest, vanunu, history, ebne, bytecode, tobruk, landesverband,
# Nearest to six: seven, five, eight, four, nine, zero, three, two,
# Nearest to at: in, olympian, after, landesverband, on, quagga, with, during,
# Nearest to some: many, these, hyi, several, webster, kiang, eigenstates, all,
# Nearest to than: or, regicide, neutronic, freya, pebble, and, defamation, retake,
# Nearest to known: such, used, lyndon, jurisdictions, villages, hyi, wonderful, part,
# Nearest to time: hyi, eider, atomic, quagga, eoka, domo, efficiencies, alexandrine,
# Nearest to these: some, many, all, such, those, equipment, both, other,
# Nearest to between: with, in, dragoons, during, seven, among, valine, concede,
# Nearest to that: which, inhibition, stadtbahn, this, however, galatea, landesverband, arctocephalus,
# Nearest to united: tetra, lacks, andree, modifiers, neutronic, travelers, galatea, banjo,
# Average loss at step  72000 :  4.8855479027
# Average loss at step  74000 :  4.82159312546
# Average loss at step  76000 :  4.79170451999
# Average loss at step  78000 :  4.60302617419
# Average loss at step  80000 :  4.72246833467
# Nearest to or: and, landesverband, than, hyi, stadtbahn, quagga, neutronic, arctocephalus,
# Nearest to three: five, four, six, two, seven, eight, one, landesverband,
# Nearest to its: their, his, the, ebne, her, inhibition, servants, kiang,
# Nearest to during: in, from, stadtbahn, neutronic, at, after, arctocephalus, landesverband,
# Nearest to not: they, arctocephalus, it, still, be, usually, to, also,
# Nearest to state: advancement, budapest, vanunu, bytecode, landesverband, banjo, ebne, tobruk,
# Nearest to six: seven, five, four, eight, nine, three, zero, landesverband,
# Nearest to at: in, olympian, after, landesverband, quagga, during, on, stadtbahn,
# Nearest to some: many, these, the, several, hyi, all, most, webster,
# Nearest to than: or, and, regicide, neutronic, freya, pebble, defamation, much,
# Nearest to known: such, used, lyndon, jurisdictions, hyi, seen, villages, ebne,
# Nearest to time: hyi, eider, day, atomic, year, efficiencies, eoka, twenties,
# Nearest to these: some, many, all, such, those, both, there, they,
# Nearest to between: with, in, during, dragoons, among, across, seven, hyi,
# Nearest to that: which, inhibition, this, stadtbahn, however, landesverband, galatea, kiang,
# Nearest to united: tetra, lacks, andree, neutronic, modifiers, galatea, travelers, landesverband,
# Average loss at step  82000 :  4.72776657391
# Average loss at step  84000 :  4.74614627278
# Average loss at step  86000 :  4.71927233052
# Average loss at step  88000 :  4.64205814803
# Average loss at step  90000 :  4.5944007417
# Nearest to or: and, landesverband, hyi, but, than, stadtbahn, neutronic, kiang,
# Nearest to three: four, five, seven, two, six, eight, landesverband, stadtbahn,
# Nearest to its: their, his, the, her, ebne, inhibition, kiang, servants,
# Nearest to during: in, after, from, stadtbahn, neutronic, arctocephalus, at, through,
# Nearest to not: they, still, usually, arctocephalus, often, be, it, also,
# Nearest to state: advancement, budapest, vanunu, pesce, bytecode, landesverband, ebne, banjo,
# Nearest to six: seven, four, five, eight, three, nine, landesverband, zero,
# Nearest to at: in, after, olympian, landesverband, during, quagga, stadtbahn, on,
# Nearest to some: many, these, several, all, hyi, this, various, most,
# Nearest to than: or, regicide, and, neutronic, much, but, freya, pebble,
# Nearest to known: such, used, lyndon, jurisdictions, seen, part, hyi, wonderful,
# Nearest to time: hyi, eider, day, efficiencies, year, eoka, atomic, neutronic,
# Nearest to these: some, many, those, all, such, both, there, several,
# Nearest to between: with, in, during, among, across, dragoons, seven, valine,
# Nearest to that: which, inhibition, this, however, stadtbahn, galatea, kiang, landesverband,
# Nearest to united: tetra, lacks, andree, neutronic, modifiers, galatea, travelers, of,
# Average loss at step  92000 :  4.29838070595
# Average loss at step  94000 :  4.49947780633
# Average loss at step  96000 :  4.44105198002
# Average loss at step  98000 :  4.54378566146
# Average loss at step  100000 :  4.56507882643
# Nearest to or: and, but, than, hyi, landesverband, neutronic, kiang, arctocephalus,
# Nearest to three: four, five, six, seven, two, eight, landesverband, nine,
# Nearest to its: their, his, the, her, ebne, inhibition, kiang, this,
# Nearest to during: in, after, at, stadtbahn, neutronic, arctocephalus, through, from,
# Nearest to not: they, it, arctocephalus, be, still, usually, often, to,
# Nearest to state: advancement, budapest, vanunu, pesce, bytecode, landesverband, government, ebne,
# Nearest to six: seven, four, five, eight, three, nine, zero, two,
# Nearest to at: in, during, after, olympian, landesverband, on, quagga, includes,
# Nearest to some: many, these, several, the, all, hyi, any, this,
# Nearest to than: or, and, but, regicide, much, neutronic, freya, pebble,
# Nearest to known: such, used, jurisdictions, seen, lyndon, hyi, part, well,
# Nearest to time: day, eider, hyi, efficiencies, year, eoka, inhibition, quagga,
# Nearest to these: some, many, all, such, those, both, there, several,
# Nearest to between: with, in, among, during, dragoons, across, hyi, valine,
# Nearest to that: which, inhibition, however, this, stadtbahn, galatea, also, what,
# Nearest to united: tetra, lacks, neutronic, andree, modifiers, galatea, travelers, same,

# %%
def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
    assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
    plt.figure(figsize=(18, 18))  # in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i, :]
        plt.scatter(x, y)
        plt.annotate(label,
                     xy=(x, y),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')

    plt.savefig(filename)

    
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
plot_only = 500
low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
labels = [reverse_dictionary[i] for i in xrange(plot_only)]
plot_with_labels(low_dim_embs, labels)
